# %% [markdown]
# <p>
# <font size='5' face='Georgia, Arial'>IIC-2233 Apunte Programación Avanzada</font><br>
# <font size='1'> Material creado por Equipo Docente IIC2233. Modificado en 2021-1 al 2023-1 por Equipo Docente IIC2233</font>
# </p>

# %% [markdown]
# # Tabla de contenidos
#
# 1. [API (*Application Programming Interface*)](#API-(Application-Programming-Interface))
# 2. [HTTP (***Hypertext Transfer Protocol***)](#HTTP-(Hypertext-Transfer-Protocol))
# 3. [*Client-side script*](#Client-side-script)
#     1. [Ejemplo consumiendo una API (método get)](#Ejemplo-consumiendo-una-API-(método-get))
#     2. [Retorno de una API](#Retorno-de-una-API)
#     3. [Uso de `post`](#Uso-de-post)
#     4. [Autenticación en _headers_](#Autenticación-en-headers)
#     5. [Caso aplicado: API de GITHUB](#Caso-aplicado:-API-de-GITHUB)
# 4. [*Server-side App*](#Server-side-App)

# %% [markdown]
# Durante el capítulo de *networking* aprendimos el uso de *sockets* y algunos protocolos para establecer la comunicación a través de una arquitectura cliente-servidor. En este capítulo, revisaremos la comunicación entre dos dispositivos mediante la **web**.
#
# ***Web services*** es el conjunto de aplicaciones cliente-servidor que se comunican a través de la web mediante un protocolo diseñado para ello. Podemos ver este tipo de servicios como aplicaciones que pueden ser accedidas por otras aplicaciones a través de una red de computadores (internet).
#
# Por ejemplo, cuando nuestro navegador (cliente) consume un sitio web (servidor), por cada **llamada al servidor**, una aplicación escrita en algún lenguaje de programación **envía una respuesta** en [HTML](https://es.wikipedia.org/wiki/HTML) (el lenguaje que se utiliza para definir la estructura de un sitio web) para que nuestro navegador la despliegue. Los _web services_ funcionan de forma similar, donde la salida está dirigida a una **aplicación que consume** esta información. Para que la comunicación sea posible, el formato de los mensajes debe ser conocido por ambas partes, para que la información pueda ser interpretada correctamente.

# %% [markdown]
# ## API (*Application Programming Interface*)
#
# En general se conoce como **API** al conjunto de funciones que son expuestas por un servicio para ser utilizadas por otros programas. Podemos ver al servicio como una clase, y a la API como el conjunto de métodos de esa clase. El servicio puede ser un *web service* o cualquier paquete que exponga una interfaz, por ejemplo una librería de Python. Sin embargo, en este capítulo cuando hablemos de API nos estaremos refiriendo a los métodos expuestos por un servicio web (un *web service*).
#
# Una gran parte de los servicios actuales exponen una API, y permiten que otras aplicaciones se conectan a ellas. De esta manera podemos construir aplicaciones que utilizan servicios que se encuentren en computadores remotos, e interactuar con ellos.
#
# En una red de computadores, cada página web de internet es almacenada en un computador remoto que
# ejecuta un proceso servidor. Un servidor remoto es simplemente un programa que escucha *requests*
# (solicitudes) y envía *responses* (respuestas) de acuerdo a un protocolo.
#
#
# Tú puedes utilizar tu propio computador para servir un sitio web. De hecho, los desarrolladores de *software* usan sus propios computadores como servidores locales al crear sitios web antes de publicarlos al mundo.
#
# Cuando escribes https://www.facebook.com en tu navegador, este envía una *request* a un servidor remoto de Facebook. Una vez que tu navegador recibe la respuesta del servidor, este la interpreta y despliega una página para ti.
#
# Para el navegador (cliente), el servidor de Facebook es una API. Esto significa que cada vez que tú visitas una página en la web, tú interactúas con alguna API en un servidor remoto. Una API no es lo mismo que un servidor remoto, pero es la parte de este que recibe las *requests* y envía *responses* (respuestas).
#
# Si cada objeto tecnológico de tu casa expusiera una API, podrías controlarla completamente desde tu celular o desde cualquier programa en Python u otro lenguaje (ver más en [internet de las cosas](https://es.wikipedia.org/wiki/Internet_de_las_cosas)).

# %% [markdown]
# ## HTTP (***Hypertext Transfer Protocol***)
#
# Gran parte de las arquitecturas de *web services* se basan en el uso del protocolo **HTTP**. Este protocolo de aplicación está encargado de proporcionar una capa para realización de transacciones y así permitir la comunicación entre clientes y servidores. HTTP trabaja como un protocolo ***request-response*** en donde el cliente hace una solicitud (*request*) y el servidor responde con la información solicitada (*response*).
#
# HTTP es un protocolo en el que el servidor no guarda ninguna información de las conexiones. Por ejemplo, al acceder a métodos de un servicio web que requiere identificación del cliente, este deberá en cada consulta enviar **algo** que acredite su identidad.
#
# El funcionamiento de este protocolo se basa en la definición de métodos o verbos que indican la acción a desarrollar por un determinado recurso. Los recursos pueden ser datos existentes en el servidor (por ejemplo, archivos) o bien una salida generada dinámicamente. La versión HTTP/1.1 incluye **cinco** métodos:
#
# - `GET`: recupera una representación de un recurso sin cambiar nada en el servidor.
# - `POST`: crea un recurso.
# - `PATCH`: aplica modificaciones parciales a un recurso.
# - `PUT`: reemplaza completamente un recurso existente.
# - `DELETE`: elimina un recurso.
#
# HTTP incluye también un conjunto de códigos de estado mediante los cuales se entrega información al cliente sobre el resultado de su petición. Algunos códigos comunes de respuesta son:
#
# - `200` : OK. Solicitud exitosa.
# - `403` : Prohibido. La petición es aceptada, pero el servidor rechaza responderla.
# - `404` : No encontrado. El recurso solicitado no ha sido encontrado.
# - `500` : Error interno del servidor.
#
# Para más detalle de los códigos pueden revisar el siguiente [enlace]( http://www.w3schools.com/tags/ref_httpmessages.asp).
#
# La siguiente figura muestra un ejemplo con la estructura de los mensaje HTTP para la *request* del cliente y para la *response* desde el servidor.
#
# ![](imgs/http_message.png)

# %% [markdown]
# ## *Client-side script*
#
# En esta sección veremos, desde el punto de vista del cliente, cómo efectuar *requests* a un servidor que mantiene un servicio web. En Python, la librería `requests` nos permite interactuar con servicios disponibles en algún *web service*. La librería, además, integra los métodos para serialización en JSON.
#
# Para instalar la librería `requests`, en cualquier terminal debes correr el comando `pip3 install requests`. Otra opción, es ejecutar la siguiente celda, que instalará la librería en el mismo entorno en que estés corriendo este jupyter (de todas maneras recomendamos instalarlo desde la consola):

# %%
import requests

# %% [markdown]
# Para generar una petición mediante `GET` usamos el método `get(url)` que recibe por argumento el llamado al recurso.

# %%
# Esta url contiene la dirección del web service 
# y los parámetros que se requiren para la consulta
url = 'https://api.github.com/repos/IIC2233/Syllabus/issues/8'
response = requests.get(url)

# %%
response?
# Out:
# Type:        Response
# String form: <Response [200]>
# File:        c:\users\mativ\appdata\local\programs\python\python310\lib\site-packages\requests\models.py
# Docstring:
# The :class:`Response <Response>` object, which contains a
# server's response to an HTTP request.

# %% [markdown]
# Luego podemos usar `.status_code` para saber el código  de estado de la consulta.

# %%
print(f'Status: {response.status_code}')
# Out:
# Status: 200

# %%
# El output de esta respuesta particular
# puede ser transformado desde JSON a dict
print(response.json()['body'])
# Out:
# Hola, luego de seguir los pasos para instalar Jupyter, al ejecutar el comando jupyter notebook, se me abre una ventana en blanco que contiene solo el logo de Jupyter arriba a la izquierda, mientras que en la terminal me aparece el siguiente código:
#
# ```
# [I 2023-08-10 17:12:51.873 ServerApp] Package notebook took 0.0000s to import
# [I 2023-08-10 17:12:51.875 ServerApp] notebook | extension was successfully linked.
# [I 2023-08-10 17:12:51.913 ServerApp] notebook | extension was successfully loaded.
# [I 2023-08-10 17:12:51.914 ServerApp] Serving notebooks from local directory: /Users/oliviallanos
# [I 2023-08-10 17:12:51.914 ServerApp] Jupyter Server 2.7.0 is running at:
# [I 2023-08-10 17:12:51.914 ServerApp] http://localhost:8888/tree?token=680d2a29734f1f0ed1f902b9403e79da37629126061ade1b
# [I 2023-08-10 17:12:51.914 ServerApp]     http://127.0.0.1:8888/tree?token=680d2a29734f1f0ed1f902b9403e79da37629126061ade1b
# [I 2023-08-10 17:12:51.914 ServerApp] Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
# [C 2023-08-10 17:12:51.916 ServerApp]
#
#     To access the server, open this file in a browser:
#         file:///Users/oliviallanos/Library/Jupyter/runtime/jpserver-60881-open.html
#     Or copy and paste one of these URLs:
#         http://localhost:8888/tree?token=680d2a29734f1f0ed1f902b9403e79da37629126061ade1b
#         http://127.0.0.1:8888/tree?token=680d2a29734f1f0ed1f902b9403e79da37629126061ade1b
# [W 2023-08-10 17:12:53.583 JupyterNotebookApp] Missing or misshapen translation settings schema:
#     HTTP 404: Not Found (Schema not found: /opt/homebrew/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/share/jupyter/lab/schemas/@jupyterlab/translation-extension/plugin.json)
# [W 2023-08-10 17:12:53.583 JupyterNotebookApp] Settings directory does not exist at /opt/homebrew/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/share/jupyter/lab/schemas
# [W 2023-08-10 17:12:53.609 JupyterNotebookApp] Missing or misshapen translation settings schema:
#     HTTP 404: Not Found (Schema not found: /opt/homebrew/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/share/jupyter/lab/schemas/@jupyterlab/translation-extension/plugin.json)
# [W 2023-08-10 17:12:53.609 ServerApp] 404 GET /lab/api/settings/@jupyter-notebook/application-extension:shell?1691701973607 (::1): Schema not found: /opt/homebrew/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/share/jupyter/lab/schemas/@jupyter-notebook/application-extension/shell.json
# [W 2023-08-10 17:12:53.609 JupyterNotebookApp] wrote error: 'Schema not found: /opt/homebrew/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/share/jupyter/lab/schemas/@jupyter-notebook/application-extension/shell.json'
#     Traceback (most recent call last):
#       File "/opt/homebrew/lib/python3.10/site-packages/tornado/web.py", line 1784, in _execute
#         result = method(*self.path_args, **self.path_kwargs)
#       File "/opt/homebrew/lib/python3.10/site-packages/tornado/web.py", line 3290, in wrapper
#         return method(self, *args, **kwargs)
#       File "/opt/homebrew/lib/python3.10/site-packages/jupyterlab_server/settings_handler.py", line 48, in get
#         result, warnings = get_settings(
#       File "/opt/homebrew/lib/python3.10/site-packages/jupyterlab_server/settings_utils.py", line 370, in get_settings
#         schema, version = _get_schema(schemas_dir, schema_name, overrides, labextensions_path)
#       File "/opt/homebrew/lib/python3.10/site-packages/jupyterlab_server/settings_utils.py", line 47, in _get_schema
#         raise web.HTTPError(404, notfound_error % path)
#     tornado.web.HTTPError: HTTP 404: Not Found (Schema not found: /opt/homebrew/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/share/jupyter/lab/schemas/@jupyter-notebook/application-extension/shell.json)
# [W 2023-08-10 17:12:53.611 JupyterNotebookApp] 404 GET /lab/api/settings/@jupyter-notebook/application-extension:shell?1691701973607 (07083e89f5584385899dde25b6f9a871@::1) 2.95ms referer=http://localhost:8888/tree
# [W 2023-08-10 17:12:53.612 JupyterNotebookApp] Missing or misshapen translation settings schema:
#     HTTP 404: Not Found (Schema not found: /opt/homebrew/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/share/jupyter/lab/schemas/@jupyterlab/translation-extension/plugin.json)
# [W 2023-08-10 17:12:53.612 ServerApp] 404 GET /lab/api/settings/@jupyterlab/translation-extension:plugin?1691701973607 (::1): Schema not found: /opt/homebrew/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/share/jupyter/lab/schemas/@jupyterlab/translation-extension/plugin.json
# [W 2023-08-10 17:12:53.613 JupyterNotebookApp] wrote error: 'Schema not found: /opt/homebrew/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/share/jupyter/lab/schemas/@jupyterlab/translation-extension/plugin.json'
#     Traceback (most recent call last):
#       File "/opt/homebrew/lib/python3.10/site-packages/tornado/web.py", line 1784, in _execute
#         result = method(*self.path_args, **self.path_kwargs)
#       File "/opt/homebrew/lib/python3.10/site-packages/tornado/web.py", line 3290, in wrapper
#         return method(self, *args, **kwargs)
#       File "/opt/homebrew/lib/python3.10/site-packages/jupyterlab_server/settings_handler.py", line 48, in get
#         result, warnings = get_settings(
#       File "/opt/homebrew/lib/python3.10/site-packages/jupyterlab_server/settings_utils.py", line 370, in get_settings
#         schema, version = _get_schema(schemas_dir, schema_name, overrides, labextensions_path)
#       File "/opt/homebrew/lib/python3.10/site-packages/jupyterlab_server/settings_utils.py", line 47, in _get_schema
#         raise web.HTTPError(404, notfound_error % path)
#     tornado.web.HTTPError: HTTP 404: Not Found (Schema not found: /opt/homebrew/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/share/jupyter/lab/schemas/@jupyterlab/translation-extension/plugin.json)
# ```
#
# ![56EC7035-3B0C-4DAD-9928-A2927826515F](https://github.com/IIC2233/Syllabus/assets/141786962/de44ec95-cefb-4738-bd8c-ad3bd691b7fb)

# %% [markdown]
# ## Ejemplo consumiendo una API (método `get`)
#
# A continuación vamos a experimentar con la API de [_fakerapi_](https://fakerapi.it/api/v1/). Esta nos genera difentes tipo clase de información inventada. Por ejemplo, nombre de personas, libros, etc.
#
# En primer lugar, todas las APIs tendrán una **URL BASE**, que consiste en un _link_ de prefijo que toda consulta debe tener. Para el caso de _fakeapi_, esta URL BASE es `"https://fakerapi.it/api/v1/"`. Por lo tanto, cualquier solicitud que hagamos, debe partir con ese prefijo.
#
# Luego, tenemos los **_endpoint_**. Para efectos del curso, podemos considerar estos **_endpoints_** como las diferentes rutas que dispone la API para hacer consultas. Para el caso de _fakeapi_, algunos **_endpoints_** son
#
# * `books/`: nos retornará información de libros inventados.
# * `texts/`: nos retornará textos inventados.
# * `person/`: nos retornará información de personas inventadas.
# * `addresses/` nos retornará direcciones inventadas.
#
# Por lo tanto, para consultar esta API, deberemos combinar la **URL BASE** con un **_endpoint**. De este modo, a URL final sería `"https://fakerapi.it/api/v1/books"`, `"https://fakerapi.it/api/v1/addresses"`, entre otros. Siempre que visitemos una API, esta nos detallará los diferentes _endpoints_ que tiene.
#
# Vamos a probar los primeros 2 **_endpoints_** de _fakerapi_.

# %%
BASE = "https://fakerapi.it/api/v1/"
endpoint_1 = "books/"

solicitud = requests.get(BASE + endpoint_1)

# imprimir el status_code
print(solicitud.status_code)
# Out:
# 200

# %% [markdown]
# Ahora vamos a ver el contenido de la consulta

# %%
data = solicitud.json()
print("Llaves: ", data.keys())
# Out:
# Llaves:  dict_keys(['status', 'code', 'total', 'data'])

# %%
data["total"]
# Out:
# 10

# %%
data['data'][0]
# Out:
# {'id': 1,
#  'title': 'I\'ll be jury,".',
#  'author': 'Stevie Purdy',
#  'genre': 'Animi',
#  'description': "March Hare. 'Yes, please do!' but the Mouse to Alice with one finger; and the White Rabbit, jumping up and repeat something now. Tell her to speak good English); 'now I'm opening out like the right.",
#  'isbn': '9789600756364',
#  'image': 'http://placeimg.com/480/640/any',
#  'published': '1977-10-14',
#  'publisher': 'Sint Dolorum'}

# %%
data["data"][0]["title"]
# Out:
# 'I\'ll be jury,".'

# %%
data['data'][9]
# Out:
# {'id': 10,
#  'title': "YET,' she said.",
#  'author': 'Jerry Nolan',
#  'genre': 'Iusto',
#  'description': "It doesn't look like one, but it just now.' 'It's the first witness,' said the last concert!' on which the words 'EAT ME' were beautifully marked in currants. 'Well, I'll eat it,' said the March.",
#  'isbn': '9793820287560',
#  'image': 'http://placeimg.com/480/640/any',
#  'published': '2011-11-03',
#  'publisher': 'Et Accusantium'}

# %% [markdown]
# Cómo podemos notar, nos inventó el nombre, género y descripción de un libro. Ahora vamos a hacer una consulta al endpoint de `"texts/`.

# %%
endpoint_2 = "texts/"

solicitud = requests.get(BASE + endpoint_2)

data = solicitud.json()
data['data'][:4]
# Out:
# [{'title': "King, 'and don't.",
#   'author': 'Diego Bednar',
#   'genre': 'Repellat',
#   'content': "Five! Don't go splashing paint over me like a stalk out of its right paw round, 'lives a Hatter: and in another moment, when she went in search of her voice. Nobody moved. 'Who cares for you?' said."},
#  {'title': 'VERY wide, but she.',
#   'author': 'Bryce Goodwin',
#   'genre': 'Non',
#   'content': "Alice severely. 'What are you getting on now, my dear?' it continued, turning to the door, and knocked. 'There's no such thing!' Alice was so full of smoke from one of them attempted to explain the."},
#  {'title': 'THE VOICE OF THE.',
#   'author': 'Tyrel Crona',
#   'genre': 'Deserunt',
#   'content': "As for pulling me out of court! Suppress him! Pinch him! Off with his knuckles. It was the first to speak. 'What size do you call him Tortoise--' 'Why did they live at the March Hare said to."},
#  {'title': 'Alice panted as.',
#   'author': 'Katrina Toy',
#   'genre': 'Sed',
#   'content': 'I\'ve nothing to do." Said the mouse doesn\'t get out." Only I don\'t think,\' Alice went on, taking first one side and up I goes like a mouse, you know. Please, Ma\'am, is this New Zealand or.'}]

# %% [markdown]
# ### Parámetros de una consulta
#
# Cada **_endpoint_** puede tener sus parámetros para personalizar la consulta.
#
# Por un lado, _fakeapi_ tiene algunos parámetros que sirve para cualquier **_endpoint_**. Uno de estos es `"_quantity"`, y nos permite indicar la cantidad de elementos a inventar. Por defecto es 10, pero ahora vamos a cambiarlo a 3.
#
# Por otro lado, el **_endpoint_** de `texts/` tiene un parámetro específico llamado `"_characters"`. Este permite indicar la cantidad de caracteres a utilizar en el texto que inventará. Por defecto es 200, pero ahora vamos a cambiarlo a 20.

# %%
endpoint_2 = "texts/"

parametros = {"_quantity": 1000, "_characters": 10}
solicitud = requests.get(BASE + endpoint_2, params=parametros)

data = solicitud.json()
data['data']
# Out:
# [{'title': 'Dormouse turned.',
#   'author': 'Kevin McDermott',
#   'genre': 'Ducimus',
#   'content': 'Alice.'},
#  {'title': 'Luckily for Alice.',
#   'author': 'Aiden Heaney',
#   'genre': 'Nam',
#   'content': "I don't."},
#  {'title': "I don't know,' he.",
#   'author': 'Jaylan Schaefer',
#   'genre': 'Reprehenderit',
#   'content': '.'},
#  {'title': "Mock Turtle. 'Very.",
#   'author': 'Natalia Wiza',
#   'genre': 'Perferendis',
#   'content': 'There.'},
#  {'title': "I wouldn't be so.",
#   'author': 'Cydney Kling',
#   'genre': 'Suscipit',
#   'content': 'I grow.'},
#  {'title': 'Alice. One of the.',
#   'author': 'Trisha Parisian',
#   'genre': 'Veritatis',
#   'content': 'Alice.'},
#  {'title': "Puss,' she began.",
#   'author': 'Kennedy Tillman',
#   'genre': 'Est',
#   'content': 'Eaglet.'},
#  {'title': 'I used--and I.',
#   'author': 'Steve Nitzsche',
#   'genre': 'Saepe',
#   'content': 'THEIR.'},
#  {'title': "I'll come up: if.",
#   'author': 'Matteo Bins',
#   'genre': 'Ut',
#   'content': 'I am.'},
#  {'title': 'There seemed to be.',
#   'author': 'Zion Price',
#   'genre': 'Earum',
#   'content': 'Soup?.'},
#  {'title': 'And yet I wish you.',
#   'author': 'Irving Bergstrom',
#   'genre': 'Ea',
#   'content': 'CAN all.'},
#  {'title': 'So she tucked her.',
#   'author': 'Elva Price',
#   'genre': 'A',
#   'content': 'You see.'},
#  {'title': "Don't let him know.",
#   'author': 'Ariane Keeling',
#   'genre': 'Voluptatum',
#   'content': 'Cheshire.'},
#  {'title': "Majesty,' said the.",
#   'author': 'Althea Pouros',
#   'genre': 'Ut',
#   'content': 'The cook.'},
#  {'title': 'The judge, by the.',
#   'author': 'Leda Moen',
#   'genre': 'Et',
#   'content': 'Latin.'},
#  {'title': 'And beat him when.',
#   'author': 'Sean Buckridge',
#   'genre': 'Magni',
#   'content': 'King.'},
#  {'title': 'Involved in this.',
#   'author': 'Bettye Bednar',
#   'genre': 'Consequatur',
#   'content': '.'},
#  {'title': 'She is such a.',
#   'author': 'Lisette Heller',
#   'genre': 'Non',
#   'content': 'His.'},
#  {'title': 'Alice looked at.',
#   'author': 'Cheyenne Langosh',
#   'genre': 'Voluptates',
#   'content': 'Queen.'},
#  {'title': 'They all returned.',
#   'author': 'Gabrielle Runolfsdottir',
#   'genre': 'Dolor',
#   'content': 'I used.'},
#  {'title': 'CAN all that green.',
#   'author': 'Euna Carter',
#   'genre': 'Sunt',
#   'content': 'Hatter.'},
#  {'title': "Mock Turtle yet?'.",
#   'author': 'Turner Jacobson',
#   'genre': 'Eum',
#   'content': 'Alice.'},
#  {'title': 'Bill, the Lizard).',
#   'author': 'Wendy Crist',
#   'genre': 'Et',
#   'content': 'She said.'},
#  {'title': 'Alice, with a.',
#   'author': 'Treva Emard',
#   'genre': 'Vero',
#   'content': 'I will.'},
#  {'title': 'Geography. London.',
#   'author': 'Phyllis Stoltenberg',
#   'genre': 'Quo',
#   'content': 'They all.'},
#  {'title': 'Just at this.',
#   'author': 'Percival McDermott',
#   'genre': 'Et',
#   'content': "It'll be."},
#  {'title': 'Dodo could not.',
#   'author': 'Rose Kihn',
#   'genre': 'Non',
#   'content': 'Dormouse.'},
#  {'title': 'But said I could.',
#   'author': 'Leanna Rosenbaum',
#   'genre': 'In',
#   'content': 'King in.'},
#  {'title': 'The March Hare.',
#   'author': 'Kayleigh Dicki',
#   'genre': 'Corrupti',
#   'content': 'Cheshire.'},
#  {'title': 'The first witness.',
#   'author': 'Paul Graham',
#   'genre': 'Omnis',
#   'content': 'Queen.'},
#  {'title': "I'd nearly.",
#   'author': 'Madelyn Gorczany',
#   'genre': 'Aut',
#   'content': 'Alice.'},
#  {'title': "Alice. 'Why?' 'IT.",
#   'author': 'Humberto Feeney',
#   'genre': 'Ullam',
#   'content': "There's."},
#  {'title': 'When I used to.',
#   'author': 'Dusty Barton',
#   'genre': 'Voluptates',
#   'content': 'Alice.'},
#  {'title': "I don't.",
#   'author': 'Isabella Mosciski',
#   'genre': 'Hic',
#   'content': 'M, such.'},
#  {'title': "I can't take.",
#   'author': 'Terrill Weber',
#   'genre': 'Veniam',
#   'content': "Alice's."},
#  {'title': "Ann!' said the.",
#   'author': 'Virginie Schoen',
#   'genre': 'Voluptatum',
#   'content': 'Hatter.'},
#  {'title': 'Dodo suddenly.',
#   'author': 'Kasey Tremblay',
#   'genre': 'Qui',
#   'content': 'Alice.'},
#  {'title': 'Alice in a.',
#   'author': 'Ashly Stokes',
#   'genre': 'Voluptatem',
#   'content': 'Alice.'},
#  {'title': 'Queen of Hearts.',
#   'author': 'Demarcus Hill',
#   'genre': 'Reprehenderit',
#   'content': 'I then?.'},
#  {'title': 'Footman seemed to.',
#   'author': 'Arne Schamberger',
#   'genre': 'Fugit',
#   'content': 'I then?.'},
#  {'title': "Rome--no, THAT'S.",
#   'author': 'Tyreek Zieme',
#   'genre': 'Dolorem',
#   'content': 'I.'},
#  {'title': 'Some of the trees.',
#   'author': 'Ayden Spencer',
#   'genre': 'Qui',
#   'content': 'Said the.'},
#  {'title': "Mock Turtle is.'.",
#   'author': 'Heath Marvin',
#   'genre': 'Fuga',
#   'content': 'By this.'},
#  {'title': "Duchess: you'd.",
#   'author': 'Bessie Koelpin',
#   'genre': 'Quos',
#   'content': 'When the.'},
#  {'title': 'I know THAT well.',
#   'author': 'Eleanore McLaughlin',
#   'genre': 'Doloribus',
#   'content': 'The.'},
#  {'title': 'RETURNED FROM HIM.',
#   'author': 'Cletus Howe',
#   'genre': 'Aut',
#   'content': "I can't."},
#  {'title': 'Mary Ann, what ARE.',
#   'author': 'Gina Tillman',
#   'genre': 'Non',
#   'content': 'Queen!.'},
#  {'title': 'When the pie was.',
#   'author': 'Korey Robel',
#   'genre': 'Saepe',
#   'content': 'Mock.'},
#  {'title': 'I said "What.',
#   'author': 'Landen Kiehn',
#   'genre': 'Nulla',
#   'content': 'She was.'},
#  {'title': 'Allow me to him.',
#   'author': 'Cleve Mante',
#   'genre': 'Voluptatem',
#   'content': 'The Cat.'},
#  {'title': "I look like it?'.",
#   'author': 'Augustine Dicki',
#   'genre': 'Ab',
#   'content': 'Gryphon.'},
#  {'title': 'Cat went on.',
#   'author': 'Jaclyn Schmidt',
#   'genre': 'Qui',
#   'content': 'Alice.'},
#  {'title': 'Next came the.',
#   'author': 'Geovany Crona',
#   'genre': 'Velit',
#   'content': 'Mock.'},
#  {'title': 'Alice hastily.',
#   'author': 'Demarco Ondricka',
#   'genre': 'Natus',
#   'content': 'In.'},
#  {'title': "I've finished.' So.",
#   'author': 'Ford Moen',
#   'genre': 'Sit',
#   'content': 'Seven.'},
#  {'title': "Queen. 'You make.",
#   'author': 'Golda Marks',
#   'genre': 'Omnis',
#   'content': 'I wonder.'},
#  {'title': "Which shall sing?'.",
#   'author': 'Carley Runte',
#   'genre': 'At',
#   'content': 'Mouse.'},
#  {'title': 'She pitied him.',
#   'author': 'Jordy Oberbrunner',
#   'genre': 'Odio',
#   'content': 'However.'},
#  {'title': 'This did not seem.',
#   'author': 'Devyn McGlynn',
#   'genre': 'Porro',
#   'content': 'The.'},
#  {'title': 'Mabel after all.',
#   'author': 'Carolyn Wyman',
#   'genre': 'Animi',
#   'content': 'The Mock.'},
#  {'title': 'CAN I have none.',
#   'author': 'Henry Lang',
#   'genre': 'Iusto',
#   'content': 'First.'},
#  {'title': "I've often seen a.",
#   'author': 'Ettie Heidenreich',
#   'genre': 'Nobis',
#   'content': 'And she.'},
#  {'title': "I'm never sure.",
#   'author': 'Garrett Kohler',
#   'genre': 'At',
#   'content': '.'},
#  {'title': 'He looked.',
#   'author': 'Monserrate Stamm',
#   'genre': 'Vitae',
#   'content': 'Rabbit.'},
#  {'title': 'And the Gryphon at.',
#   'author': 'Cornell DuBuque',
#   'genre': 'Maxime',
#   'content': '.'},
#  {'title': 'Alice, that she.',
#   'author': 'Marc Considine',
#   'genre': 'Amet',
#   'content': 'Alice.'},
#  {'title': "ME,' but.",
#   'author': 'Lera Satterfield',
#   'genre': 'Ea',
#   'content': 'Alice.'},
#  {'title': 'Alice did not like.',
#   'author': 'Jayden Schulist',
#   'genre': 'Iure',
#   'content': 'Mock.'},
#  {'title': 'Duchess sneezed.',
#   'author': 'Chad Lakin',
#   'genre': 'Excepturi',
#   'content': 'March.'},
#  {'title': "Gryphon, 'she.",
#   'author': 'Alba Smith',
#   'genre': 'Rerum',
#   'content': 'Gryphon.'},
#  {'title': 'I was going to.',
#   'author': 'Fae Runolfsson',
#   'genre': 'Placeat',
#   'content': 'However.'},
#  {'title': 'Presently she.',
#   'author': 'Brayan Swift',
#   'genre': 'Vel',
#   'content': 'Queen.'},
#  {'title': 'Dormouse, who.',
#   'author': 'Zola Lakin',
#   'genre': 'Autem',
#   'content': 'Alice as.'},
#  {'title': "Queen. 'Well, I.",
#   'author': 'Jerrod Osinski',
#   'genre': 'Ipsa',
#   'content': 'CHAPTER.'},
#  {'title': "Alice sadly. 'Hand.",
#   'author': 'Rosalee Sauer',
#   'genre': 'Rem',
#   'content': 'Gryphon.'},
#  {'title': 'YOU must.',
#   'author': 'Icie Abernathy',
#   'genre': 'Officiis',
#   'content': 'Dormouse.'},
#  {'title': 'There could be NO.',
#   'author': 'Macey Metz',
#   'genre': 'Quos',
#   'content': 'Gryphon.'},
#  {'title': 'But here, to.',
#   'author': 'Kelley Reinger',
#   'genre': 'Soluta',
#   'content': 'Owl, as.'},
#  {'title': "Turtle.' These.",
#   'author': 'Layne Parker',
#   'genre': 'Quo',
#   'content': 'Alice.'},
#  {'title': 'King said to the.',
#   'author': 'Delbert Wolf',
#   'genre': 'Aut',
#   'content': 'King.'},
#  {'title': 'Sir, With no jury.',
#   'author': 'Terrence Ratke',
#   'genre': 'Sapiente',
#   'content': 'Alice.'},
#  {'title': 'Lobster; I heard.',
#   'author': 'Geraldine Botsford',
#   'genre': 'Aperiam',
#   'content': 'I should.'},
#  {'title': 'Alice had no very.',
#   'author': 'Bessie Reilly',
#   'genre': 'Tempora',
#   'content': 'I mean.'},
#  {'title': 'Alice, as she.',
#   'author': 'Leilani Lind',
#   'genre': 'Dolor',
#   'content': 'Gryphon.'},
#  {'title': 'Hatter, and, just.',
#   'author': "Chad O'Keefe",
#   'genre': 'Et',
#   'content': 'King.'},
#  {'title': "Hatter. 'Nor I,'.",
#   'author': 'Opal Aufderhar',
#   'genre': 'Occaecati',
#   'content': 'Cat.'},
#  {'title': 'And the Eaglet.',
#   'author': 'Annetta Block',
#   'genre': 'Impedit',
#   'content': 'Hardly.'},
#  {'title': 'I ought to have no.',
#   'author': 'Makayla Boyer',
#   'genre': 'Nihil',
#   'content': 'In a.'},
#  {'title': 'Queen in a.',
#   'author': 'Lamar Zboncak',
#   'genre': 'Dolor',
#   'content': 'I never.'},
#  {'title': 'Gryphon hastily.',
#   'author': 'Malvina Steuber',
#   'genre': 'Accusamus',
#   'content': 'She soon.'},
#  {'title': 'I used--and I.',
#   'author': 'Virgie Daugherty',
#   'genre': 'Rerum',
#   'content': 'The door.'},
#  {'title': 'She said it to.',
#   'author': 'Christa Koelpin',
#   'genre': 'Beatae',
#   'content': 'Let me.'},
#  {'title': "Alice; 'it's laid.",
#   'author': 'Lora Hauck',
#   'genre': 'Rerum',
#   'content': 'Indeed.'},
#  {'title': "English); 'now I'm.",
#   'author': 'Royce Lesch',
#   'genre': 'Libero',
#   'content': 'She.'},
#  {'title': "Time!' 'Perhaps.",
#   'author': 'Josiane Connelly',
#   'genre': 'Et',
#   'content': 'Nile On.'},
#  {'title': "Cat, 'if you don't.",
#   'author': 'Mya Denesik',
#   'genre': 'Quae',
#   'content': 'I.'},
#  {'title': 'She stretched.',
#   'author': 'Ella Douglas',
#   'genre': 'Dolore',
#   'content': 'March.'},
#  {'title': 'RED rose-tree, and.',
#   'author': 'Gertrude Nolan',
#   'genre': 'Nihil',
#   'content': 'King.'},
#  {'title': 'Alice a little.',
#   'author': 'Benjamin Beier',
#   'genre': 'Sapiente',
#   'content': 'Mock.'},
#  {'title': 'IS that to be.',
#   'author': 'Robin Crona',
#   'genre': 'Deserunt',
#   'content': 'And he.'},
#  {'title': 'The Dormouse shook.',
#   'author': 'Lowell Quitzon',
#   'genre': 'Porro',
#   'content': 'That.'},
#  {'title': 'King, with an.',
#   'author': 'Reagan Schuster',
#   'genre': 'In',
#   'content': 'Alice to.'},
#  {'title': 'Queen, who had.',
#   'author': 'Candido Torp',
#   'genre': 'Autem',
#   'content': 'Alice.'},
#  {'title': 'CAN all that.',
#   'author': 'Bryon Cole',
#   'genre': 'Sint',
#   'content': 'Footman.'},
#  {'title': "Now you know.' 'I.",
#   'author': 'Kamren Haag',
#   'genre': 'Delectus',
#   'content': 'Gryphon.'},
#  {'title': 'As they walked off.',
#   'author': 'Omer Sipes',
#   'genre': 'Nam',
#   'content': 'March.'},
#  {'title': 'She had just begun.',
#   'author': 'Sheldon Waelchi',
#   'genre': 'Impedit',
#   'content': 'And she.'},
#  {'title': 'Alice, whose.',
#   'author': 'Astrid Rippin',
#   'genre': 'Ipsa',
#   'content': 'Alice.'},
#  {'title': "Cat. 'Do you know.",
#   'author': 'Duane Stoltenberg',
#   'genre': 'Illo',
#   'content': 'THAT.'},
#  {'title': 'Alice, that she.',
#   'author': 'Kurt Carter',
#   'genre': 'Temporibus',
#   'content': '.'},
#  {'title': 'She felt that she.',
#   'author': 'Vergie Torp',
#   'genre': 'Sint',
#   'content': 'Nobody.'},
#  {'title': "HERE.' 'But then,'.",
#   'author': 'Wilfrid Huel',
#   'genre': 'Error',
#   'content': 'Rabbit.'},
#  {'title': "Alice, 'and why it.",
#   'author': 'Hertha Connelly',
#   'genre': 'Enim',
#   'content': 'Alice.'},
#  {'title': 'Alice began in a.',
#   'author': 'Georgianna Hand',
#   'genre': 'Aut',
#   'content': '.'},
#  {'title': "And I declare it's.",
#   'author': 'Blanche Steuber',
#   'genre': 'Ad',
#   'content': 'Alice.'},
#  {'title': 'The Mouse only.',
#   'author': 'Araceli Breitenberg',
#   'genre': 'Rerum',
#   'content': 'Hatter.'},
#  {'title': 'The Fish-Footman.',
#   'author': 'Derek Quitzon',
#   'genre': 'Rerum',
#   'content': '.'},
#  {'title': 'Alice, and her.',
#   'author': 'Leopold Kilback',
#   'genre': 'In',
#   'content': 'NOT a.'},
#  {'title': 'There was not a.',
#   'author': 'Brianne Herman',
#   'genre': 'Voluptates',
#   'content': 'Alice an.'},
#  {'title': "Cat. 'Do you take.",
#   'author': 'Pansy Hamill',
#   'genre': 'Error',
#   'content': 'So Alice.'},
#  {'title': 'Alice for.',
#   'author': 'Maximo Monahan',
#   'genre': 'Molestiae',
#   'content': 'And she.'},
#  {'title': 'Alice! Come here.',
#   'author': 'Jody Hickle',
#   'genre': 'At',
#   'content': 'Footman.'},
#  {'title': 'I only knew the.',
#   'author': 'Cloyd Wolff',
#   'genre': 'Quia',
#   'content': '.'},
#  {'title': 'Alice to herself.',
#   'author': 'Jacky Volkman',
#   'genre': 'In',
#   'content': 'I.'},
#  {'title': "Heads below!' (a.",
#   'author': 'Regan Runolfsdottir',
#   'genre': 'Non',
#   'content': 'Mock.'},
#  {'title': 'Her listeners were.',
#   'author': 'Guido Gusikowski',
#   'genre': 'Tempora',
#   'content': 'Alice.'},
#  {'title': 'Allow me to.',
#   'author': 'Jedidiah Herzog',
#   'genre': 'Dolore',
#   'content': 'Gryphon.'},
#  {'title': 'I should.',
#   'author': 'Kattie Schmeler',
#   'genre': 'Aut',
#   'content': 'Gryphon.'},
#  {'title': 'ONE respectable.',
#   'author': 'Verdie Kutch',
#   'genre': 'Odit',
#   'content': 'Mock.'},
#  {'title': 'Queen of Hearts.',
#   'author': 'Forest Dibbert',
#   'genre': 'Blanditiis',
#   'content': 'I beat.'},
#  {'title': 'Alice, so please.',
#   'author': 'Jena Gorczany',
#   'genre': 'Qui',
#   'content': '.'},
#  {'title': 'Seven flung down.',
#   'author': 'Eva Jacobson',
#   'genre': 'Harum',
#   'content': 'Alice.'},
#  {'title': 'She waited for a.',
#   'author': 'Bartholome Mann',
#   'genre': 'Quasi',
#   'content': 'This.'},
#  {'title': 'Alice to herself.',
#   'author': 'Graham Pacocha',
#   'genre': 'Illo',
#   'content': 'Said he.'},
#  {'title': 'Alice replied, so.',
#   'author': 'Polly Ritchie',
#   'genre': 'Dolorum',
#   'content': 'Alice.'},
#  {'title': "I don't know,' he.",
#   'author': 'Deondre Koelpin',
#   'genre': 'Sit',
#   'content': 'I shall.'},
#  {'title': 'Mock Turtle Soup.',
#   'author': 'Ressie Hermiston',
#   'genre': 'Natus',
#   'content': 'I ask!.'},
#  {'title': "Queen?' said the.",
#   'author': 'Angelita Ryan',
#   'genre': 'Et',
#   'content': 'He was.'},
#  {'title': 'Rabbit, and had.',
#   'author': 'Monroe Carter',
#   'genre': 'Commodi',
#   'content': 'This.'},
#  {'title': 'Alice in a tone of.',
#   'author': 'Jordane Glover',
#   'genre': 'Sint',
#   'content': 'Hatter.'},
#  {'title': 'Alice in a moment.',
#   'author': 'Willa Ondricka',
#   'genre': 'Et',
#   'content': '.'},
#  {'title': 'Alice started to.',
#   'author': 'Gretchen Friesen',
#   'genre': 'Tenetur',
#   'content': 'Knave of.'},
#  {'title': 'I could let you.',
#   'author': 'Enid Konopelski',
#   'genre': 'Inventore',
#   'content': 'WAS a.'},
#  {'title': 'WHAT? The other.',
#   'author': 'Emmy Thompson',
#   'genre': 'Et',
#   'content': 'Miss.'},
#  {'title': "Alice, 'or perhaps.",
#   'author': 'Anya Bode',
#   'genre': 'Ipsa',
#   'content': 'I must.'},
#  {'title': 'Dormouse sulkily.',
#   'author': 'Jody Lowe',
#   'genre': 'Delectus',
#   'content': 'Gryphon.'},
#  {'title': 'Alice recognised.',
#   'author': 'Glenna Smitham',
#   'genre': 'Sit',
#   'content': 'I only.'},
#  {'title': 'Alice in a great.',
#   'author': 'Sim Parisian',
#   'genre': 'Aut',
#   'content': 'Alice.'},
#  {'title': 'Queen, pointing to.',
#   'author': "Bruce O'Conner",
#   'genre': 'Voluptas',
#   'content': '.'},
#  {'title': "Alice; 'I might as.",
#   'author': 'Franz Breitenberg',
#   'genre': 'Sapiente',
#   'content': 'Silence.'},
#  {'title': "Pigeon. 'I can.",
#   'author': 'Alan Stark',
#   'genre': 'Aliquid',
#   'content': "Turtle.'."},
#  {'title': 'Alice soon came.',
#   'author': 'Casandra Ullrich',
#   'genre': 'Odio',
#   'content': 'Has.'},
#  {'title': 'Mock Turtle.',
#   'author': 'Logan Bayer',
#   'genre': 'Omnis',
#   'content': 'Alice, a.'},
#  {'title': 'I am so VERY.',
#   'author': 'Haven Veum',
#   'genre': 'Deserunt',
#   'content': '.'},
#  {'title': 'Alice was a dead.',
#   'author': 'Cathrine Leannon',
#   'genre': 'Corporis',
#   'content': 'Mock.'},
#  {'title': 'Mouse had changed.',
#   'author': 'Timmothy Johns',
#   'genre': 'Aspernatur',
#   'content': 'Alice.'},
#  {'title': 'Alice for.',
#   'author': 'Caterina Cole',
#   'genre': 'Error',
#   'content': 'VERY.'},
#  {'title': "So she began: 'O.",
#   'author': 'Pauline DuBuque',
#   'genre': 'Iste',
#   'content': 'Gryphon.'},
#  {'title': 'I COULD NOT.',
#   'author': 'Rod Walker',
#   'genre': 'Voluptate',
#   'content': 'Why, I.'},
#  {'title': "Hatter. 'I deny.",
#   'author': 'Giovanna Williamson',
#   'genre': 'Molestiae',
#   'content': 'Alice.'},
#  {'title': 'Gryphon, and.',
#   'author': 'Clare Herman',
#   'genre': 'Ipsa',
#   'content': 'France.'},
#  {'title': 'Alice quite.',
#   'author': 'Kari Runolfsdottir',
#   'genre': 'Tenetur',
#   'content': "I'll."},
#  {'title': 'King said to.',
#   'author': 'Jett Zulauf',
#   'genre': 'Ut',
#   'content': 'Alice.'},
#  {'title': 'However, this.',
#   'author': 'Wade Friesen',
#   'genre': 'Maxime',
#   'content': 'Rabbit.'},
#  {'title': 'Alice was.',
#   'author': 'Kane Cole',
#   'genre': 'Vel',
#   'content': 'Then.'},
#  {'title': 'The Mock Turtle in.',
#   'author': "Edna O'Kon",
#   'genre': 'Aperiam',
#   'content': 'English.'},
#  {'title': 'Rabbit noticed.',
#   'author': 'Ari Feest',
#   'genre': 'Officiis',
#   'content': 'YOUR.'},
#  {'title': 'Dinah my dear! I.',
#   'author': 'Cooper Mitchell',
#   'genre': 'Quam',
#   'content': 'The.'},
#  {'title': 'Queen, and Alice.',
#   'author': 'Keanu Heathcote',
#   'genre': 'Nisi',
#   'content': 'I ever.'},
#  {'title': 'Duchess.',
#   'author': 'Destiney Boehm',
#   'genre': 'Nihil',
#   'content': 'And.'},
#  {'title': "DON'T know,' said.",
#   'author': 'Jammie Klein',
#   'genre': 'Nulla',
#   'content': 'Alice.'},
#  {'title': 'But they HAVE.',
#   'author': 'Guy Kessler',
#   'genre': 'Distinctio',
#   'content': 'Mock.'},
#  {'title': "I'm not Ada,' she.",
#   'author': 'Jeanne Parisian',
#   'genre': 'Deserunt',
#   'content': 'Mabel!.'},
#  {'title': 'He looked.',
#   'author': 'Alison Kertzmann',
#   'genre': 'Placeat',
#   'content': 'Gryphon.'},
#  {'title': "THAT like?' said.",
#   'author': 'Colleen Ryan',
#   'genre': 'Est',
#   'content': 'Nobody.'},
#  {'title': 'Alice indignantly.',
#   'author': 'Meggie Braun',
#   'genre': 'Et',
#   'content': 'White.'},
#  {'title': 'Queen will hear.',
#   'author': 'Guido Pfeffer',
#   'genre': 'Ea',
#   'content': 'At this.'},
#  {'title': 'Those whom she.',
#   'author': 'Roberta Howe',
#   'genre': 'Beatae',
#   'content': "Hare. 'I."},
#  {'title': 'And here Alice.',
#   'author': 'Grace Roob',
#   'genre': 'Quia',
#   'content': 'Turtle.'},
#  {'title': 'Time as well go in.',
#   'author': 'Sienna Gulgowski',
#   'genre': 'Ea',
#   'content': 'White.'},
#  {'title': 'And the moral of.',
#   'author': 'Rosalia Collier',
#   'genre': 'Ut',
#   'content': 'King.'},
#  {'title': 'She stretched.',
#   'author': 'Guiseppe VonRueden',
#   'genre': 'Voluptatem',
#   'content': 'Either.'},
#  {'title': 'King said to the.',
#   'author': 'Dudley Smitham',
#   'genre': 'In',
#   'content': 'Just as.'},
#  {'title': 'Caterpillar. Alice.',
#   'author': 'Sarina Littel',
#   'genre': 'Error',
#   'content': 'Mock.'},
#  {'title': "Please, Ma'am, is.",
#   'author': 'Aletha Wolf',
#   'genre': 'Ullam',
#   'content': "I'm."},
#  {'title': "Hatter: 'it's very.",
#   'author': 'Lacy Murazik',
#   'genre': 'Necessitatibus',
#   'content': "Queen's."},
#  {'title': 'Who ever saw one.',
#   'author': 'Ryan Bahringer',
#   'genre': 'Quasi',
#   'content': "RABBIT'."},
#  {'title': 'Alice ventured to.',
#   'author': 'Fanny Blanda',
#   'genre': 'Culpa',
#   'content': 'Who for.'},
#  {'title': "I don't take this.",
#   'author': 'Shane Borer',
#   'genre': 'Consequuntur',
#   'content': 'She.'},
#  {'title': "I? Ah, THAT'S the.",
#   'author': 'Troy VonRueden',
#   'genre': 'Dolorum',
#   'content': "Bill,'."},
#  {'title': 'There are no mice.',
#   'author': 'Myrna Grady',
#   'genre': 'Perferendis',
#   'content': 'Footman.'},
#  {'title': 'Mock Turtle Soup.',
#   'author': 'Simone Jacobson',
#   'genre': 'Nisi',
#   'content': "THAT'S."},
#  {'title': 'The Rabbit started.',
#   'author': 'Monte Okuneva',
#   'genre': 'Dolores',
#   'content': 'The.'},
#  {'title': 'So they got.',
#   'author': 'Royal Koelpin',
#   'genre': 'Sunt',
#   'content': 'THIS.'},
#  {'title': 'A bright idea came.',
#   'author': 'Ellen Huels',
#   'genre': 'Labore',
#   'content': 'The.'},
#  {'title': 'Hatter: and in a.',
#   'author': 'Alvah Gleichner',
#   'genre': 'Fugiat',
#   'content': 'Those.'},
#  {'title': 'Alice, and she.',
#   'author': 'Rudy Muller',
#   'genre': 'Consectetur',
#   'content': 'Then.'},
#  {'title': 'The Cat seemed to.',
#   'author': 'Mario Blanda',
#   'genre': 'Blanditiis',
#   'content': "ME'."},
#  {'title': 'As they walked off.',
#   'author': 'Fernando Bahringer',
#   'genre': 'Delectus',
#   'content': 'Game, or.'},
#  {'title': 'Alice joined the.',
#   'author': 'Ramon Breitenberg',
#   'genre': 'Et',
#   'content': 'CHAPTER.'},
#  {'title': 'What made you so.',
#   'author': 'Mario Kris',
#   'genre': 'Eos',
#   'content': 'At last.'},
#  {'title': 'William the.',
#   'author': 'Agustin Lebsack',
#   'genre': 'Corporis',
#   'content': 'Mock.'},
#  {'title': 'I beg your.',
#   'author': 'Vena Quitzon',
#   'genre': 'Aut',
#   'content': 'ARE OLD.'},
#  {'title': "Why, I haven't had.",
#   'author': "Harold D'Amore",
#   'genre': 'Amet',
#   'content': 'Queen.'},
#  {'title': 'She was a table.',
#   'author': 'Icie Walter',
#   'genre': 'Voluptas',
#   'content': 'First.'},
#  {'title': 'The King turned.',
#   'author': 'Declan Ondricka',
#   'genre': 'Occaecati',
#   'content': 'They.'},
#  {'title': 'Oh dear! I shall.',
#   'author': 'Jonathan Abernathy',
#   'genre': 'Aut',
#   'content': "I'm I."},
#  {'title': 'King triumphantly.',
#   'author': 'Domingo Lockman',
#   'genre': 'Voluptas',
#   'content': 'Alice.'},
#  {'title': 'Pool of Tears.',
#   'author': 'Lyla Sawayn',
#   'genre': 'Est',
#   'content': 'Rabbit.'},
#  {'title': 'But they HAVE.',
#   'author': 'Glenna Weimann',
#   'genre': 'Eos',
#   'content': 'Father.'},
#  {'title': 'CHAPTER V. Advice.',
#   'author': 'America Murray',
#   'genre': 'Alias',
#   'content': 'Mock.'},
#  {'title': "Alice; 'I can't go.",
#   'author': 'Walker Parker',
#   'genre': 'Non',
#   'content': 'Gryphon.'},
#  {'title': 'I fancied that.',
#   'author': 'Elian Yost',
#   'genre': 'Itaque',
#   'content': "ONE.'."},
#  {'title': "Alice's side as.",
#   'author': 'Lazaro Jacobs',
#   'genre': 'Accusantium',
#   'content': 'Alice.'},
#  {'title': 'While the Owl and.',
#   'author': 'Ruben Runte',
#   'genre': 'Minima',
#   'content': '.'},
#  {'title': 'I think it so VERY.',
#   'author': "Lillie O'Connell",
#   'genre': 'Ipsam',
#   'content': 'NO.'},
#  {'title': 'VERY good.',
#   'author': 'Anna DuBuque',
#   'genre': 'Tempora',
#   'content': 'Heads.'},
#  {'title': "Mouse. '--I.",
#   'author': 'Cleo Jenkins',
#   'genre': 'Nihil',
#   'content': 'Cat.'},
#  {'title': 'Duck and a piece.',
#   'author': 'Burdette Heller',
#   'genre': 'Iure',
#   'content': 'Alice.'},
#  {'title': "SHE, of course,'.",
#   'author': 'Gaylord Runte',
#   'genre': 'Adipisci',
#   'content': 'Mock.'},
#  {'title': 'Hatter: and in his.',
#   'author': 'Brooklyn Williamson',
#   'genre': 'Dignissimos',
#   'content': "I'm."},
#  {'title': 'Owl, as a lark.',
#   'author': 'Carlee Schinner',
#   'genre': 'Repellendus',
#   'content': '.'},
#  {'title': 'Alice panted as.',
#   'author': 'Tressie Osinski',
#   'genre': 'Eaque',
#   'content': "I've."},
#  {'title': 'Alice said.',
#   'author': 'Tatyana Dach',
#   'genre': 'Et',
#   'content': '.'},
#  {'title': 'She said the March.',
#   'author': 'Zula Haag',
#   'genre': 'Debitis',
#   'content': 'ONE with.'},
#  {'title': 'First, she dreamed.',
#   'author': 'Alanna Kuhic',
#   'genre': 'Eos',
#   'content': 'And.'},
#  {'title': 'Queen till she.',
#   'author': 'Prudence Ryan',
#   'genre': 'Aliquid',
#   'content': '.'},
#  {'title': 'As she said to.',
#   'author': 'Carol Will',
#   'genre': 'Non',
#   'content': 'AT ALL.'},
#  {'title': "Turtle.' These.",
#   'author': 'Emiliano Kub',
#   'genre': 'Repellendus',
#   'content': 'And she.'},
#  {'title': "Come on!' So they.",
#   'author': 'Nathen Wolf',
#   'genre': 'Et',
#   'content': 'Duchess!.'},
#  {'title': "Alice. 'Then it.",
#   'author': 'Milton Howe',
#   'genre': 'Mollitia',
#   'content': 'I can.'},
#  {'title': 'Dormouse is asleep.',
#   'author': 'Sylvia Lowe',
#   'genre': 'Corrupti',
#   'content': 'I do.'},
#  {'title': 'The Mock Turtle.',
#   'author': 'Albin Moore',
#   'genre': 'Sunt',
#   'content': 'Time.'},
#  {'title': 'As she said to.',
#   'author': 'Viola Wuckert',
#   'genre': 'Porro',
#   'content': 'I was a.'},
#  {'title': "Don't let him know.",
#   'author': 'Letha Windler',
#   'genre': 'Deleniti',
#   'content': 'Alice.'},
#  {'title': 'The Queen had only.',
#   'author': 'Micheal Howell',
#   'genre': 'Sed',
#   'content': 'Gryphon.'},
#  {'title': 'By the use of a.',
#   'author': 'Eli Prohaska',
#   'genre': 'Rerum',
#   'content': 'Hatter.'},
#  {'title': 'Quadrille The Mock.',
#   'author': 'Ivy Schaefer',
#   'genre': 'Voluptatem',
#   'content': "I've had."},
#  {'title': "YOU?' said the.",
#   'author': 'Ubaldo Altenwerth',
#   'genre': 'Maxime',
#   'content': 'She soon.'},
#  {'title': 'Then it got down.',
#   'author': 'Glenna Wyman',
#   'genre': 'Doloribus',
#   'content': 'They had.'},
#  {'title': 'Alice, and she.',
#   'author': 'Jana Harvey',
#   'genre': 'Perspiciatis',
#   'content': 'Gryphon.'},
#  {'title': 'Beautiful.',
#   'author': 'Daphnee Carroll',
#   'genre': 'Mollitia',
#   'content': 'Alice.'},
#  {'title': 'Alice, (she had.',
#   'author': 'Eve Rice',
#   'genre': 'Et',
#   'content': 'Indeed.'},
#  {'title': "I hadn't quite.",
#   'author': 'Gerard Fadel',
#   'genre': 'Non',
#   'content': 'Dodo.'},
#  {'title': 'However.',
#   'author': 'Dovie Bernier',
#   'genre': 'Ad',
#   'content': 'Laughing.'},
#  {'title': 'I was a little.',
#   'author': 'Frida Purdy',
#   'genre': 'Repellendus',
#   'content': 'CHAPTER.'},
#  {'title': "It's by far the.",
#   'author': 'Mireille Monahan',
#   'genre': 'Veniam',
#   'content': 'It.'},
#  {'title': 'The Queen had only.',
#   'author': 'Amiya Herzog',
#   'genre': 'Dicta',
#   'content': 'It was.'},
#  {'title': 'Rabbit was no.',
#   'author': 'Roosevelt Ortiz',
#   'genre': 'Similique',
#   'content': 'Allow me.'},
#  {'title': 'RED rose-tree, and.',
#   'author': 'Marion Rippin',
#   'genre': 'Assumenda',
#   'content': 'Soup, so.'},
#  {'title': 'I could say if I.',
#   'author': 'Chadrick Durgan',
#   'genre': 'Voluptatem',
#   'content': 'Alice.'},
#  {'title': 'She ate a little.',
#   'author': 'Jerad Johns',
#   'genre': 'Et',
#   'content': 'Gryphon.'},
#  {'title': 'Caterpillar. Alice.',
#   'author': 'Marisol Lang',
#   'genre': 'Et',
#   'content': 'Dodo.'},
#  {'title': "Gryphon. 'Turn a.",
#   'author': 'Crystal Hansen',
#   'genre': 'Consequatur',
#   'content': 'Alice.'},
#  {'title': 'Bill, the Lizard).',
#   'author': 'Kody Gleichner',
#   'genre': 'Omnis',
#   'content': 'Queen.'},
#  {'title': "I'm Mabel, I'll.",
#   'author': 'Bella Hartmann',
#   'genre': 'Eum',
#   'content': "ME'."},
#  {'title': "I know!' exclaimed.",
#   'author': 'Dejah Senger',
#   'genre': 'Perferendis',
#   'content': 'Mouse.'},
#  {'title': "I!' he replied.",
#   'author': "Brandy O'Hara",
#   'genre': 'Enim',
#   'content': 'As soon.'},
#  {'title': 'Gryphon whispered.',
#   'author': 'Henderson Reynolds',
#   'genre': 'In',
#   'content': 'Mock.'},
#  {'title': 'There seemed to.',
#   'author': 'Danial Champlin',
#   'genre': 'Repellat',
#   'content': 'Gryphon.'},
#  {'title': 'TWO little.',
#   'author': 'Flo Halvorson',
#   'genre': 'Iste',
#   'content': 'What.'},
#  {'title': 'King said to the.',
#   'author': 'Thea Mueller',
#   'genre': 'Nihil',
#   'content': "Queen's."},
#  {'title': 'Alice noticed with.',
#   'author': 'Brett Muller',
#   'genre': 'Soluta',
#   'content': "I'm a."},
#  {'title': 'March Hare and his.',
#   'author': 'Liza Reichel',
#   'genre': 'Velit',
#   'content': 'Suddenly.'},
#  {'title': 'CHAPTER IV. The.',
#   'author': 'Pierre Medhurst',
#   'genre': 'Ut',
#   'content': 'Alice.'},
#  {'title': 'The Mouse looked.',
#   'author': 'Freddie Mante',
#   'genre': 'Laborum',
#   'content': 'Queen.'},
#  {'title': 'Dormouse crossed.',
#   'author': 'Randal King',
#   'genre': 'Est',
#   'content': 'Alice.'},
#  {'title': 'Alice replied in a.',
#   'author': 'Lola Kuvalis',
#   'genre': 'Libero',
#   'content': 'Mouse.'},
#  {'title': 'Dodo could not.',
#   'author': 'Halle Kris',
#   'genre': 'Et',
#   'content': 'Alice.'},
#  {'title': "It's enough to get.",
#   'author': 'Mack Will',
#   'genre': 'Omnis',
#   'content': 'Alice.'},
#  {'title': "Come on!' So they.",
#   'author': 'Robbie Crona',
#   'genre': 'Facilis',
#   'content': "Queen's."},
#  {'title': 'Alice, a good.',
#   'author': 'Mervin Volkman',
#   'genre': 'Rem',
#   'content': 'As they.'},
#  {'title': "Why, there's.",
#   'author': 'Hallie Willms',
#   'genre': 'Pariatur',
#   'content': 'Alice.'},
#  {'title': "Bill's place for a.",
#   'author': 'Eleazar Bradtke',
#   'genre': 'Voluptates',
#   'content': 'O.'},
#  {'title': 'White Rabbit read.',
#   'author': 'Isac Volkman',
#   'genre': 'Nihil',
#   'content': 'Queen.'},
#  {'title': "I don't.",
#   'author': 'Sherman Thiel',
#   'genre': 'Ab',
#   'content': 'However.'},
#  {'title': 'Dodo replied very.',
#   'author': 'Lorena Purdy',
#   'genre': 'Sint',
#   'content': 'As she.'},
#  {'title': 'King put on your.',
#   'author': 'Thomas Padberg',
#   'genre': 'Officia',
#   'content': 'Allow me.'},
#  {'title': 'And beat him when.',
#   'author': 'Skylar Corkery',
#   'genre': 'Odit',
#   'content': 'Then.'},
#  {'title': 'Alice went on.',
#   'author': 'Myrtle Feest',
#   'genre': 'Fugit',
#   'content': 'And in.'},
#  {'title': 'Cheshire Cat: now.',
#   'author': 'Ignatius Schinner',
#   'genre': 'Laudantium',
#   'content': 'The.'},
#  {'title': 'VERY nearly at the.',
#   'author': 'Aditya Purdy',
#   'genre': 'Voluptatem',
#   'content': 'Rabbit.'},
#  {'title': 'Shakespeare, in.',
#   'author': 'Clarissa Stokes',
#   'genre': 'Quas',
#   'content': 'An.'},
#  {'title': "Alice. 'Now we.",
#   'author': 'Adrianna Barton',
#   'genre': 'Et',
#   'content': 'Alice.'},
#  {'title': 'Hatter, with an.',
#   'author': 'Percy Labadie',
#   'genre': 'Fugit',
#   'content': "I know!'."},
#  {'title': "Why, I wouldn't.",
#   'author': 'Ron Schumm',
#   'genre': 'Vel',
#   'content': '.'},
#  {'title': "Gryphon. 'Then.",
#   'author': 'Moises Labadie',
#   'genre': 'Ducimus',
#   'content': "Cat. 'I."},
#  {'title': 'QUEEN OF HEARTS.',
#   'author': 'Hadley Cassin',
#   'genre': 'Et',
#   'content': 'Mouse.'},
#  {'title': 'CHAPTER IV. The.',
#   'author': 'Moshe Friesen',
#   'genre': 'Magnam',
#   'content': 'All this.'},
#  {'title': 'King was the Cat.',
#   'author': 'Emmie Bernhard',
#   'genre': 'Quos',
#   'content': 'When.'},
#  {'title': 'French.',
#   'author': 'Hunter Altenwerth',
#   'genre': 'Aliquid',
#   'content': 'This.'},
#  {'title': "Hatter, 'you.",
#   'author': 'Jena Bode',
#   'genre': 'Suscipit',
#   'content': "I hadn't."},
#  {'title': "Alice, 'or perhaps.",
#   'author': 'Raquel Wiza',
#   'genre': 'Vero',
#   'content': 'King.'},
#  {'title': 'The pepper when he.',
#   'author': 'Malvina Legros',
#   'genre': 'Et',
#   'content': 'Dodo.'},
#  {'title': "Dinn may be,' said.",
#   'author': 'Colin Murray',
#   'genre': 'Error',
#   'content': 'Even the.'},
#  {'title': 'March Hare went.',
#   'author': 'Ebony Kreiger',
#   'genre': 'Soluta',
#   'content': "I don't."},
#  {'title': "Bill's got to the.",
#   'author': 'Pasquale Lubowitz',
#   'genre': 'Vero',
#   'content': 'There.'},
#  {'title': 'A little.',
#   'author': 'Colt Ledner',
#   'genre': 'Sapiente',
#   'content': 'Queen of.'},
#  {'title': 'CHAPTER VIII. The.',
#   'author': 'Samson Reinger',
#   'genre': 'Modi',
#   'content': 'Alice.'},
#  {'title': 'The Knave shook.',
#   'author': 'Wayne Schiller',
#   'genre': 'Fuga',
#   'content': '.'},
#  {'title': 'The Dormouse again.',
#   'author': 'Kaleigh Wyman',
#   'genre': 'Ut',
#   'content': 'Pigeon.'},
#  {'title': "And it'll fetch.",
#   'author': 'Alexie Weissnat',
#   'genre': 'Fugiat',
#   'content': 'March.'},
#  {'title': 'I am to see its.',
#   'author': 'Grayce Senger',
#   'genre': 'Vel',
#   'content': 'Gryphon.'},
#  {'title': 'Alice; not that.',
#   'author': 'Citlalli Kling',
#   'genre': 'Ullam',
#   'content': 'I shall.'},
#  {'title': 'She went on again.',
#   'author': 'Helga Kunde',
#   'genre': 'Illo',
#   'content': 'Alice.'},
#  {'title': "Tortoise--' 'Why.",
#   'author': 'Hassie Hayes',
#   'genre': 'Impedit',
#   'content': 'Alice.'},
#  {'title': 'The King laid his.',
#   'author': 'Ramona Emard',
#   'genre': 'Voluptatibus',
#   'content': 'Indeed.'},
#  {'title': 'I sleep" is the.',
#   'author': 'Jedidiah Schuppe',
#   'genre': 'Dolore',
#   'content': 'Alice in.'},
#  {'title': "I'm perfectly sure.",
#   'author': 'Lauryn Cummings',
#   'genre': 'Aliquid',
#   'content': 'Heads.'},
#  {'title': 'Bill! the master.',
#   'author': 'Jude Thompson',
#   'genre': 'Numquam',
#   'content': 'While.'},
#  {'title': "Alice again. 'No.",
#   'author': 'Madison Cummerata',
#   'genre': 'Cumque',
#   'content': 'The.'},
#  {'title': 'I get" is the.',
#   'author': 'Luisa Lowe',
#   'genre': 'Hic',
#   'content': 'Rabbit.'},
#  {'title': 'Alice laughed so.',
#   'author': 'Georgette Gutkowski',
#   'genre': 'Fugit',
#   'content': 'The.'},
#  {'title': "Alice. 'I'M not a.",
#   'author': 'Lea Davis',
#   'genre': 'Voluptatem',
#   'content': 'The.'},
#  {'title': 'VERY long claws.',
#   'author': 'Rachel Stamm',
#   'genre': 'Ea',
#   'content': 'Alice.'},
#  {'title': 'Gryphon hastily.',
#   'author': 'Burnice Gleichner',
#   'genre': 'Modi',
#   'content': 'Rabbit.'},
#  {'title': 'She felt that she.',
#   'author': 'Christine Bauch',
#   'genre': 'Officiis',
#   'content': "Queen,'."},
#  {'title': 'The only things in.',
#   'author': 'Bryana Rempel',
#   'genre': 'Et',
#   'content': 'Queen.'},
#  {'title': 'Alice led the way.',
#   'author': 'Myrtice Stark',
#   'genre': 'Eum',
#   'content': 'She was.'},
#  {'title': 'Tortoise, if he.',
#   'author': 'Leone Rice',
#   'genre': 'Qui',
#   'content': 'There.'},
#  {'title': "I'd taken the.",
#   'author': "Vernice O'Keefe",
#   'genre': 'Ut',
#   'content': 'Tell us.'},
#  {'title': 'Alice would not.',
#   'author': 'Kole Jacobi',
#   'genre': 'Inventore',
#   'content': 'Alice.'},
#  {'title': "Gryphon: 'I went.",
#   'author': 'Leila Homenick',
#   'genre': 'Consequatur',
#   'content': "I'm."},
#  {'title': "Alice. 'It goes.",
#   'author': 'Arvid Heidenreich',
#   'genre': 'Ipsam',
#   'content': 'The.'},
#  {'title': 'And the.',
#   'author': 'Kaden Larkin',
#   'genre': 'Consequuntur',
#   'content': 'Alice.'},
#  {'title': 'It means much the.',
#   'author': 'Annie Fahey',
#   'genre': 'Maxime',
#   'content': 'Alice.'},
#  {'title': 'Alice could bear.',
#   'author': 'Amani Ritchie',
#   'genre': 'Est',
#   'content': '.'},
#  {'title': 'The Gryphon lifted.',
#   'author': 'Kraig Kohler',
#   'genre': 'Sunt',
#   'content': 'I wonder.'},
#  {'title': 'Gryphon only.',
#   'author': 'Verdie Haley',
#   'genre': 'Eius',
#   'content': 'Alice.'},
#  {'title': 'How the Owl and.',
#   'author': 'Daphnee Ernser',
#   'genre': 'Tenetur',
#   'content': 'Indeed.'},
#  {'title': 'Alice, feeling.',
#   'author': 'Shaylee Murray',
#   'genre': 'Consectetur',
#   'content': "I'll."},
#  {'title': 'Soup," will you.',
#   'author': 'Rowan Hettinger',
#   'genre': 'Similique',
#   'content': 'DOTH THE.'},
#  {'title': "I dare say you're.",
#   'author': 'Clementina McDermott',
#   'genre': 'Corporis',
#   'content': '.'},
#  {'title': 'March Hare was.',
#   'author': 'Joaquin Yundt',
#   'genre': 'Veritatis',
#   'content': 'I ever.'},
#  {'title': 'Caterpillar. Here.',
#   'author': 'Gregorio Stroman',
#   'genre': 'Perferendis',
#   'content': '.'},
#  {'title': 'White Rabbit.',
#   'author': 'Beverly Schaden',
#   'genre': 'Aut',
#   'content': "Ma!'."},
#  {'title': 'You gave us three.',
#   'author': 'Ismael Cruickshank',
#   'genre': 'Et',
#   'content': "There's."},
#  {'title': 'Alice would not.',
#   'author': 'Afton Schmeler',
#   'genre': 'Non',
#   'content': 'DOTH THE.'},
#  {'title': 'Then followed the.',
#   'author': 'Era Gusikowski',
#   'genre': 'Et',
#   'content': 'Alice.'},
#  {'title': 'Alice could hardly.',
#   'author': 'Makenzie Dietrich',
#   'genre': 'Qui',
#   'content': 'Duchess.'},
#  {'title': 'And in she went.',
#   'author': 'Joey Brekke',
#   'genre': 'Pariatur',
#   'content': 'And she.'},
#  {'title': 'Canterbury, found.',
#   'author': 'Audra Schumm',
#   'genre': 'Accusamus',
#   'content': '.'},
#  {'title': 'Pigeon had.',
#   'author': 'Maci Walter',
#   'genre': 'Pariatur',
#   'content': 'She was.'},
#  {'title': "The Cat's head.",
#   'author': 'Ernie Gleason',
#   'genre': 'Eos',
#   'content': '.'},
#  {'title': 'Alice again, in a.',
#   'author': 'Cicero Orn',
#   'genre': 'Sequi',
#   'content': 'She was.'},
#  {'title': 'As soon as she.',
#   'author': 'Alejandrin Bernhard',
#   'genre': 'Odio',
#   'content': 'The.'},
#  {'title': 'March Hare.',
#   'author': 'Lew Rosenbaum',
#   'genre': 'Qui',
#   'content': 'Let me.'},
#  {'title': "Pigeon; 'but I.",
#   'author': 'Abby Gleichner',
#   'genre': 'Inventore',
#   'content': 'SAID.'},
#  {'title': 'I wish you could.',
#   'author': 'Lucas Wilderman',
#   'genre': 'Voluptas',
#   'content': 'Advice.'},
#  {'title': 'Caterpillar.',
#   'author': 'Lucious Wiza',
#   'genre': 'Possimus',
#   'content': 'Alice.'},
#  {'title': "COULD! I'm sure I.",
#   'author': 'Jonathan Jones',
#   'genre': 'Assumenda',
#   'content': 'I see"!\'.'},
#  {'title': "Queen. 'I haven't.",
#   'author': 'Myriam Quigley',
#   'genre': 'Molestiae',
#   'content': 'Mock.'},
#  {'title': 'Then followed the.',
#   'author': 'Jermaine Ledner',
#   'genre': 'Aspernatur',
#   'content': "I'm."},
#  {'title': 'Alice as he came.',
#   'author': 'Margot Rempel',
#   'genre': 'Aperiam',
#   'content': 'Crab, a.'},
#  {'title': 'An obstacle that.',
#   'author': 'Maximillia Waters',
#   'genre': 'Maiores',
#   'content': '.'},
#  {'title': 'I to do this, so.',
#   'author': 'Reginald Murazik',
#   'genre': 'Labore',
#   'content': 'The poor.'},
#  {'title': 'She went in search.',
#   'author': 'Shayne Keebler',
#   'genre': 'Voluptatem',
#   'content': 'Mock.'},
#  {'title': 'A little.',
#   'author': 'Hardy Roberts',
#   'genre': 'Quis',
#   'content': 'I can.'},
#  {'title': "Rabbit's voice.",
#   'author': 'Iliana Johns',
#   'genre': 'Assumenda',
#   'content': "Rabbit's."},
#  {'title': 'Alice, thinking it.',
#   'author': 'Kirsten Aufderhar',
#   'genre': 'Delectus',
#   'content': 'Then it.'},
#  {'title': 'All the time they.',
#   'author': 'Corbin Dach',
#   'genre': 'Qui',
#   'content': 'Alice.'},
#  {'title': 'The poor little.',
#   'author': 'Isadore Hammes',
#   'genre': 'Ipsam',
#   'content': 'Oh dear!.'},
#  {'title': 'Soup, so rich and.',
#   'author': 'Lexi Kshlerin',
#   'genre': 'Amet',
#   'content': 'First.'},
#  {'title': "THERE again!' said.",
#   'author': 'Camden Rippin',
#   'genre': 'Doloribus',
#   'content': 'And will.'},
#  {'title': "Why, she'll eat a.",
#   'author': 'Marcia Ondricka',
#   'genre': 'Et',
#   'content': 'For.'},
#  {'title': "I'm doubtful about.",
#   'author': "Eldridge O'Hara",
#   'genre': 'Est',
#   'content': 'Cat.'},
#  {'title': 'The Queen turned.',
#   'author': 'Bennie Schaefer',
#   'genre': 'Temporibus',
#   'content': "Alice's."},
#  {'title': 'William the.',
#   'author': 'Jayden Runte',
#   'genre': 'Dolor',
#   'content': 'There.'},
#  {'title': "Queen's voice in.",
#   'author': 'Amelia King',
#   'genre': 'Vitae',
#   'content': 'Gryphon.'},
#  {'title': 'King, and the.',
#   'author': 'Bertha Bogan',
#   'genre': 'Repellendus',
#   'content': '.'},
#  {'title': "I don't like.",
#   'author': 'Emelie Dietrich',
#   'genre': 'Et',
#   'content': 'YOUR.'},
#  {'title': 'Alice did not.',
#   'author': 'Quentin Rolfson',
#   'genre': 'Nam',
#   'content': 'And.'},
#  {'title': "That's all.'.",
#   'author': 'Llewellyn King',
#   'genre': 'Neque',
#   'content': 'March.'},
#  {'title': 'I am to see if he.',
#   'author': 'Avery Bosco',
#   'genre': 'Totam',
#   'content': 'Alice.'},
#  {'title': 'Crab, a little.',
#   'author': 'Millie Klocko',
#   'genre': 'Similique',
#   'content': 'What.'},
#  {'title': 'Dodo. Then they.',
#   'author': 'Maribel Von',
#   'genre': 'Ut',
#   'content': 'So they.'},
#  {'title': "Dormouse,' thought.",
#   'author': 'Patrick Hayes',
#   'genre': 'Voluptas',
#   'content': '.'},
#  {'title': 'Suppress him!.',
#   'author': 'Jalen Stehr',
#   'genre': 'Quibusdam',
#   'content': 'Alice.'},
#  {'title': 'All this time she.',
#   'author': 'Willy Kassulke',
#   'genre': 'Cupiditate',
#   'content': 'Queen.'},
#  {'title': "Queen. 'Never!'.",
#   'author': 'Erick Leuschke',
#   'genre': 'Ex',
#   'content': 'I.'},
#  {'title': 'However, this.',
#   'author': 'Emely Turner',
#   'genre': 'Qui',
#   'content': 'Mock.'},
#  {'title': 'Queen, pointing to.',
#   'author': 'Laila Kirlin',
#   'genre': 'In',
#   'content': 'Dormouse.'},
#  {'title': 'Mouse replied.',
#   'author': 'Octavia Aufderhar',
#   'genre': 'Omnis',
#   'content': "I'd."},
#  {'title': 'The Cat seemed to.',
#   'author': 'Jettie Pollich',
#   'genre': 'Et',
#   'content': 'Five.'},
#  {'title': 'Alice very meekly.',
#   'author': 'Lincoln Waters',
#   'genre': 'Ut',
#   'content': 'The.'},
#  {'title': 'Majesty means, of.',
#   'author': 'Abdul Gerhold',
#   'genre': 'Perferendis',
#   'content': 'Alice.'},
#  {'title': 'And he got up this.',
#   'author': 'Geraldine Raynor',
#   'genre': 'Fuga',
#   'content': 'March.'},
#  {'title': 'I beg your.',
#   'author': 'Melany Parisian',
#   'genre': 'Voluptas',
#   'content': 'Alice.'},
#  {'title': 'I tell you, you.',
#   'author': 'Shyann Rippin',
#   'genre': 'Magnam',
#   'content': 'On.'},
#  {'title': 'CHAPTER VI. Pig.',
#   'author': 'Rocio Kuvalis',
#   'genre': 'Quis',
#   'content': "I've."},
#  {'title': 'The jury all wrote.',
#   'author': 'Maureen Spencer',
#   'genre': 'Odit',
#   'content': "Five. 'I."},
#  {'title': "D,' she added in a.",
#   'author': 'Moriah Renner',
#   'genre': 'Quia',
#   'content': 'He moved.'},
#  {'title': "M?' said Alice.",
#   'author': 'Alva Crooks',
#   'genre': 'Earum',
#   'content': 'I look.'},
#  {'title': 'How the Owl had.',
#   'author': 'Reggie Boyer',
#   'genre': 'Reiciendis',
#   'content': 'For he.'},
#  {'title': 'An enormous puppy.',
#   'author': 'Roderick Bergnaum',
#   'genre': 'Quis',
#   'content': 'Alice.'},
#  {'title': "Alice, 'a great.",
#   'author': 'Eugene Powlowski',
#   'genre': 'Dolor',
#   'content': "I'll be."},
#  {'title': 'The Footman seemed.',
#   'author': 'Casimer Kris',
#   'genre': 'Sit',
#   'content': 'Yet you.'},
#  {'title': "I've got to the.",
#   'author': 'Heather Bins',
#   'genre': 'Et',
#   'content': 'Dodo.'},
#  {'title': "Alice. 'Who's.",
#   'author': 'Kaylin Monahan',
#   'genre': 'Id',
#   'content': 'I will.'},
#  {'title': 'Suppress him!.',
#   'author': 'Amanda Swift',
#   'genre': 'Dolore',
#   'content': "M--'."},
#  {'title': "I'm a deal too far.",
#   'author': 'Lavinia Pfannerstill',
#   'genre': 'Aliquid',
#   'content': 'Cat.'},
#  {'title': "Alice's shoulder.",
#   'author': 'Nick Gleason',
#   'genre': 'Consectetur',
#   'content': '.'},
#  {'title': 'I never understood.',
#   'author': 'Karina Mraz',
#   'genre': 'Maxime',
#   'content': 'WOULD.'},
#  {'title': 'I should be raving.',
#   'author': 'Vern Towne',
#   'genre': 'Rem',
#   'content': 'Would.'},
#  {'title': 'Alice panted as.',
#   'author': 'Lucio Dare',
#   'genre': 'Omnis',
#   'content': 'Crab, a.'},
#  {'title': "English); 'now I'm.",
#   'author': 'Serenity Ziemann',
#   'genre': 'Aut',
#   'content': 'The.'},
#  {'title': 'WOULD go with.',
#   'author': 'Coy Veum',
#   'genre': 'Dolores',
#   'content': 'The.'},
#  {'title': 'And she began.',
#   'author': 'Carole Sporer',
#   'genre': 'Reprehenderit',
#   'content': 'Alice an.'},
#  {'title': "Alice, 'they're.",
#   'author': 'Timmy McGlynn',
#   'genre': 'Quia',
#   'content': 'Alice.'},
#  {'title': "Australia?' (and.",
#   'author': 'Lulu Cormier',
#   'genre': 'Eos',
#   'content': 'Alice.'},
#  {'title': 'Queen. First came.',
#   'author': 'Marlen Prosacco',
#   'genre': 'In',
#   'content': 'Alice.'},
#  {'title': 'Hatter were having.',
#   'author': 'Shane Donnelly',
#   'genre': 'Et',
#   'content': 'Alice.'},
#  {'title': 'Alice, as she.',
#   'author': 'Christiana Murphy',
#   'genre': 'Temporibus',
#   'content': 'Still.'},
#  {'title': "March Hare. 'He.",
#   'author': 'Dannie Greenholt',
#   'genre': 'Magnam',
#   'content': 'I wonder.'},
#  {'title': "Do cats eat bats?'.",
#   'author': 'Danny Schowalter',
#   'genre': 'Qui',
#   'content': 'I shall.'},
#  {'title': 'Mock Turtle.',
#   'author': "Hailie D'Amore",
#   'genre': 'Velit',
#   'content': 'I THINK.'},
#  {'title': 'And will talk in.',
#   'author': 'Bridget Howe',
#   'genre': 'Dolores',
#   'content': 'How.'},
#  {'title': 'Alice; but she.',
#   'author': 'Aaron Hagenes',
#   'genre': 'Aliquam',
#   'content': 'I shall.'},
#  {'title': 'CHAPTER X. The.',
#   'author': 'Nadia Bartoletti',
#   'genre': 'Sit',
#   'content': 'Alice.'},
#  {'title': 'Alice did not.',
#   'author': 'Lynn Erdman',
#   'genre': 'Sit',
#   'content': 'Next.'},
#  {'title': 'Mock Turtle.',
#   'author': 'Chaya Parker',
#   'genre': 'Soluta',
#   'content': 'WAS a.'},
#  {'title': 'I should be free.',
#   'author': 'Keeley Cremin',
#   'genre': 'Impedit',
#   'content': 'Hatter.'},
#  {'title': "I'm not myself.",
#   'author': 'Violet Simonis',
#   'genre': 'Aut',
#   'content': 'Alice.'},
#  {'title': 'AND.', 'author': 'Carlee Bayer', 'genre': 'Ut', 'content': 'NOT.'},
#  {'title': "Gryphon. 'We can.",
#   'author': 'Annabelle Mante',
#   'genre': 'Quis',
#   'content': "DON'T."},
#  {'title': "Dormouse. 'Don't.",
#   'author': 'Rafaela Carter',
#   'genre': 'Velit',
#   'content': '.'},
#  {'title': 'First, she tried.',
#   'author': 'Yoshiko Vandervort',
#   'genre': 'Est',
#   'content': 'HIS time.'},
#  {'title': 'When they take us.',
#   'author': 'Scotty Beier',
#   'genre': 'Et',
#   'content': 'Turtle.'},
#  {'title': 'Mouse was.',
#   'author': 'Clarabelle Koelpin',
#   'genre': 'Unde',
#   'content': 'Father.'},
#  {'title': 'Duchess.',
#   'author': 'Jerel Altenwerth',
#   'genre': 'Fuga',
#   'content': 'Alice.'},
#  {'title': "Alice. 'Anything.",
#   'author': 'Eladio Kling',
#   'genre': 'Dignissimos',
#   'content': 'Alice to.'},
#  {'title': 'Alice, in a very.',
#   'author': 'Jada Lind',
#   'genre': 'Qui',
#   'content': 'She had.'},
#  {'title': 'Alice thought to.',
#   'author': 'Ava Wintheiser',
#   'genre': 'Eum',
#   'content': "I'll."},
#  {'title': "Queen. 'It proves.",
#   'author': 'Stefanie Champlin',
#   'genre': 'Quas',
#   'content': 'No.'},
#  {'title': 'So she tucked her.',
#   'author': 'Maryjane Morar',
#   'genre': 'Sunt',
#   'content': "Cat. 'I."},
#  {'title': 'Presently she.',
#   'author': 'Mireya Terry',
#   'genre': 'Eos',
#   'content': 'The.'},
#  {'title': 'THE.',
#   'author': "Mitchel O'Conner",
#   'genre': 'Ex',
#   'content': 'Pigeon.'},
#  {'title': 'Gryphon, and.',
#   'author': 'Tobin Marks',
#   'genre': 'Omnis',
#   'content': 'VERY.'},
#  {'title': 'Footman continued.',
#   'author': 'Catherine Cassin',
#   'genre': 'Ut',
#   'content': "Queen?'."},
#  {'title': "I almost wish I'd.",
#   'author': 'Ericka Jakubowski',
#   'genre': 'Ipsa',
#   'content': 'Let this.'},
#  {'title': "She'll get me.",
#   'author': 'Ofelia Cole',
#   'genre': 'Neque',
#   'content': "IT,' the."},
#  {'title': "Oh, I shouldn't.",
#   'author': 'Conner Erdman',
#   'genre': 'Suscipit',
#   'content': 'I used.'},
#  {'title': "I meant,' the King.",
#   'author': 'Nola Prosacco',
#   'genre': 'Qui',
#   'content': 'Bill! I.'},
#  {'title': 'Do you think, at.',
#   'author': 'Zena Schiller',
#   'genre': 'Dolor',
#   'content': '.'},
#  {'title': 'WOULD go with the.',
#   'author': 'Kenna Hilpert',
#   'genre': 'Et',
#   'content': 'Will.'},
#  {'title': 'Gryphon, half to.',
#   'author': 'Claire Parisian',
#   'genre': 'Autem',
#   'content': 'Bill!.'},
#  {'title': 'Alice thought the.',
#   'author': 'Mohammed Heidenreich',
#   'genre': 'Quod',
#   'content': 'I almost.'},
#  {'title': 'As a duck with its.',
#   'author': 'Lonie Bradtke',
#   'genre': 'Voluptatibus',
#   'content': "I!' said."},
#  {'title': 'No, there were.',
#   'author': 'Adela Bednar',
#   'genre': 'Modi',
#   'content': 'Footman.'},
#  {'title': 'Dormouse.',
#   'author': 'Emiliano Abernathy',
#   'genre': 'Voluptas',
#   'content': 'As a.'},
#  {'title': "That'll be a.",
#   'author': 'Fae Cruickshank',
#   'genre': 'Recusandae',
#   'content': "Alice's."},
#  {'title': 'I had our Dinah.',
#   'author': 'Jeffery Skiles',
#   'genre': 'Nesciunt',
#   'content': 'Dodo had.'},
#  {'title': 'How she longed to.',
#   'author': 'Kayla Lubowitz',
#   'genre': 'Voluptatem',
#   'content': 'King.'},
#  {'title': "ME' were.",
#   'author': 'Candace King',
#   'genre': 'Quia',
#   'content': 'COULD.'},
#  {'title': 'The Dormouse again.',
#   'author': 'Amelia Jakubowski',
#   'genre': 'Voluptatibus',
#   'content': '.'},
#  {'title': 'Mock Turtle.',
#   'author': 'Tomasa Parker',
#   'genre': 'Corporis',
#   'content': 'Pigeon.'},
# ...
#   'genre': 'Sunt',
#   'content': 'Then the.'},
#  {'title': 'Queen left off.',
#   'author': 'Granville Kilback',
#   'genre': 'Quia',
#   'content': 'Hatter.'},
#  {'title': "Pat, what's that.",
#   'author': 'Hans Cummerata',
#   'genre': 'Optio',
#   'content': 'Cat; and.'},
#  {'title': 'I should think you.',
#   'author': 'Juvenal Mann',
#   'genre': 'Suscipit',
#   'content': 'Alice.'},
#  {'title': "Alice. 'Come on.",
#   'author': 'Manuela Bernhard',
#   'genre': 'Qui',
#   'content': 'Alice.'},
#  {'title': 'Hatter began, in a.',
#   'author': 'Cristopher Williamson',
#   'genre': 'Voluptatem',
#   'content': 'Alice.'},
#  {'title': 'Alice in a.',
#   'author': 'Jasper Walter',
#   'genre': 'Quis',
#   'content': "They're."},
#  {'title': 'The Cat seemed to.',
#   'author': 'Kamron Collier',
#   'genre': 'Adipisci',
#   'content': "I don't."},
#  {'title': "Eaglet. 'I don't.",
#   'author': 'Maiya Strosin',
#   'genre': 'Ullam',
#   'content': 'Gryphon.'},
#  {'title': "Father William,'.",
#   'author': 'Mandy Senger',
#   'genre': 'Occaecati',
#   'content': 'ONE.'},
#  {'title': 'Alice, in a voice.',
#   'author': 'Arjun Adams',
#   'genre': 'Ut',
#   'content': 'I should.'},
#  {'title': 'There was nothing.',
#   'author': 'Shaylee Muller',
#   'genre': 'Consequatur',
#   'content': 'Once.'},
#  {'title': 'Alice hastily.',
#   'author': 'Savanna Ondricka',
#   'genre': 'Amet',
#   'content': '.'},
#  {'title': 'King say in a.',
#   'author': 'Dovie Okuneva',
#   'genre': 'Laborum',
#   'content': 'France.'},
#  {'title': 'Mock Turtle.',
#   'author': 'Marcos King',
#   'genre': 'Non',
#   'content': 'First.'},
#  {'title': 'At last the Mock.',
#   'author': 'Breanna Swaniawski',
#   'genre': 'Et',
#   'content': "THIS!'."},
#  {'title': "Hatter. 'It isn't.",
#   'author': 'Lia Murphy',
#   'genre': 'Fugiat',
#   'content': 'PLEASE.'},
#  {'title': "SHE'S she, and I'm.",
#   'author': 'Amy Lakin',
#   'genre': 'Aliquam',
#   'content': 'Laughing.'},
#  {'title': "Alice, 'as all the.",
#   'author': 'Juvenal Kassulke',
#   'genre': 'Cum',
#   'content': 'ONE.'},
#  {'title': 'Queen jumped up.',
#   'author': 'Wilfred Wolff',
#   'genre': 'Qui',
#   'content': 'What.'},
#  {'title': 'Alice alone with.',
#   'author': 'Daphney Keebler',
#   'genre': 'Eligendi',
#   'content': 'Queen.'},
#  {'title': 'Alice in a very.',
#   'author': 'Julian Bradtke',
#   'genre': 'Explicabo',
#   'content': 'FOOT.'},
#  {'title': 'Alice, very much.',
#   'author': 'Eileen Torp',
#   'genre': 'Fuga',
#   'content': "I hadn't."},
#  {'title': "I won't.",
#   'author': 'Stephany Borer',
#   'genre': 'Quo',
#   'content': 'Alice.'},
#  {'title': 'The three soldiers.',
#   'author': 'Mandy Ferry',
#   'genre': 'Et',
#   'content': '.'},
#  {'title': 'The Mouse did not.',
#   'author': 'Helena Pfannerstill',
#   'genre': 'Amet',
#   'content': 'King.'},
#  {'title': 'Run home this.',
#   'author': 'Vickie Mueller',
#   'genre': 'Est',
#   'content': 'Rabbit.'},
#  {'title': 'English coast you.',
#   'author': 'Darrion Green',
#   'genre': 'Possimus',
#   'content': 'The.'},
#  {'title': 'I do it again and.',
#   'author': 'Nova Bartoletti',
#   'genre': 'Reprehenderit',
#   'content': 'So she.'},
#  {'title': 'Mock Turtle.',
#   'author': 'Jessika Mante',
#   'genre': 'Veniam',
#   'content': 'Five.'},
#  {'title': 'Alice, swallowing.',
#   'author': 'Elsa Hilpert',
#   'genre': 'Commodi',
#   'content': 'The.'},
#  {'title': "I ask! It's always.",
#   'author': 'Christ Fisher',
#   'genre': 'Voluptatem',
#   'content': 'King.'},
#  {'title': "No, no! You're a.",
#   'author': 'Bridget Weissnat',
#   'genre': 'Blanditiis',
#   'content': 'But, now.'},
#  {'title': 'VERY unpleasant.',
#   'author': 'Lonie Koch',
#   'genre': 'Quo',
#   'content': '.'},
#  {'title': 'And so it was.',
#   'author': 'Dariana Trantow',
#   'genre': 'Est',
#   'content': 'Hardly.'},
#  {'title': "Footman's head: it.",
#   'author': 'Kailyn Lesch',
#   'genre': 'Voluptatem',
#   'content': 'I.'},
#  {'title': "ME,' but.",
#   'author': 'Kadin Hahn',
#   'genre': 'Velit',
#   'content': 'Has.'},
#  {'title': "Queen. 'Can you.",
#   'author': 'George Stamm',
#   'genre': 'Veniam',
#   'content': "I hadn't."},
#  {'title': "YOUR table,' said.",
#   'author': 'Brooks Kuhic',
#   'genre': 'Omnis',
#   'content': 'Hatter.'},
#  {'title': "I? Ah, THAT'S the.",
#   'author': 'Lavina Hills',
#   'genre': 'Quibusdam',
#   'content': 'VI. Pig.'},
#  {'title': 'Next came an angry.',
#   'author': 'Arianna Lockman',
#   'genre': 'Dolorem',
#   'content': 'King.'},
#  {'title': 'I used to say.',
#   'author': 'Juwan Rippin',
#   'genre': 'Ipsam',
#   'content': '.'},
#  {'title': "Ugh, Serpent!'.",
#   'author': 'Karli Quitzon',
#   'genre': 'Qui',
#   'content': 'Mouse to.'},
#  {'title': 'Kings and Queens.',
#   'author': 'Polly Buckridge',
#   'genre': 'Debitis',
#   'content': 'Alice.'},
#  {'title': 'This question the.',
#   'author': 'Karianne McGlynn',
#   'genre': 'Quidem',
#   'content': 'Duck.'},
#  {'title': 'Gryphon remarked.',
#   'author': 'Elton Emmerich',
#   'genre': 'Nostrum',
#   'content': 'Alice.'},
#  {'title': 'The Cat seemed to.',
#   'author': 'Marge Stoltenberg',
#   'genre': 'Doloremque',
#   'content': 'I can.'},
#  {'title': 'VERY wide, but she.',
#   'author': 'Modesta Schmeler',
#   'genre': 'Omnis',
#   'content': "I've had."},
#  {'title': 'Alice said to.',
#   'author': 'Arne Hilpert',
#   'genre': 'Ut',
#   'content': 'So she.'},
#  {'title': "No room!' they.",
#   'author': 'Lizeth Bailey',
#   'genre': 'Pariatur',
#   'content': 'Queen.'},
#  {'title': 'Next came an angry.',
#   'author': 'Dawn Vandervort',
#   'genre': 'Distinctio',
#   'content': 'Duchess.'},
#  {'title': 'However, she got.',
#   'author': 'Emiliano Windler',
#   'genre': 'Sunt',
#   'content': 'Gryphon.'},
#  {'title': 'Alice coming.',
#   'author': 'Allan Schmeler',
#   'genre': 'Est',
#   'content': 'I mean.'},
#  {'title': 'Gryphon replied.',
#   'author': 'Giovani Jenkins',
#   'genre': 'Rem',
#   'content': 'No.'},
#  {'title': 'Dodo managed it.).',
#   'author': 'Vickie Botsford',
#   'genre': 'Nihil',
#   'content': 'Dodo.'},
#  {'title': "Mock Turtle. 'Very.",
#   'author': 'Mekhi Gleichner',
#   'genre': 'Eveniet',
#   'content': 'She had.'},
#  {'title': 'The miserable.',
#   'author': 'Aiyana Tremblay',
#   'genre': 'Saepe',
#   'content': '.'},
#  {'title': 'He looked at poor.',
#   'author': 'Emely Jones',
#   'genre': 'Quia',
#   'content': 'Duchess!.'},
#  {'title': 'It was the White.',
#   'author': 'Terry Hermann',
#   'genre': 'Rerum',
#   'content': 'For.'},
#  {'title': 'I had it written.',
#   'author': 'Freida Reichert',
#   'genre': 'Officia',
#   'content': 'King.'},
#  {'title': 'Said the mouse.',
#   'author': 'Christ Bradtke',
#   'genre': 'Reiciendis',
#   'content': "I'd been."},
#  {'title': 'White Rabbit.',
#   'author': 'Dale Goyette',
#   'genre': 'Vitae',
#   'content': 'Duchess!.'},
#  {'title': "Alice. 'Now we.",
#   'author': 'Alysson Mertz',
#   'genre': 'Molestias',
#   'content': 'NOT be.'},
#  {'title': 'As soon as she.',
#   'author': "Raina O'Connell",
#   'genre': 'Inventore',
#   'content': "HE was.'."},
#  {'title': "Alice, 'to speak.",
#   'author': 'Jimmy Haag',
#   'genre': 'Aut',
#   'content': 'Hatter.'},
#  {'title': 'King, looking.',
#   'author': 'Declan Mitchell',
#   'genre': 'Quis',
#   'content': 'Queen.'},
#  {'title': "Alice. 'Then it.",
#   'author': 'Jaeden Will',
#   'genre': 'Doloremque',
#   'content': "I don't."},
#  {'title': 'Improve his.',
#   'author': 'Jeramie Tromp',
#   'genre': 'Vel',
#   'content': 'Duchess.'},
#  {'title': 'I BEG your.',
#   'author': 'Rosemarie Huel',
#   'genre': 'Tenetur',
#   'content': "I've."},
#  {'title': 'King. On this the.',
#   'author': 'Durward Feest',
#   'genre': 'Odit',
#   'content': "Queen!'."},
#  {'title': 'Rabbit hastily.',
#   'author': 'Ashton Huels',
#   'genre': 'Aut',
#   'content': 'Dodo.'},
#  {'title': 'Some of the earth.',
#   'author': 'Crystal Kuphal',
#   'genre': 'Recusandae',
#   'content': "I can't."},
#  {'title': "Alice, 'and if it.",
#   'author': 'Ralph Zemlak',
#   'genre': 'Quasi',
#   'content': 'Please.'},
#  {'title': "I almost wish I'd.",
#   'author': 'Alphonso Breitenberg',
#   'genre': 'Atque',
#   'content': 'CHAPTER.'},
#  {'title': 'Mouse, getting up.',
#   'author': 'Verona Torphy',
#   'genre': 'Et',
#   'content': '.'},
#  {'title': 'Mock Turtle.',
#   'author': 'Clare Schinner',
#   'genre': 'Consequatur',
#   'content': 'WOULD.'},
#  {'title': 'There seemed to.',
#   'author': 'Raheem Wilderman',
#   'genre': 'Dignissimos',
#   'content': 'IS that.'},
#  {'title': "March Hare. 'He.",
#   'author': 'Kameron Schmidt',
#   'genre': 'Nobis',
#   'content': 'WAS a.'},
#  {'title': 'Dormouse, who was.',
#   'author': 'Madge Howe',
#   'genre': 'Saepe',
#   'content': "Five. 'I."},
#  {'title': "I'll go round and.",
#   'author': 'Roxane Heaney',
#   'genre': 'Est',
#   'content': 'Hatter.'},
#  {'title': 'WOULD go with the.',
#   'author': 'Ahmed Dietrich',
#   'genre': 'Architecto',
#   'content': 'I have.'},
#  {'title': 'Alice, in a.',
#   'author': 'Queen Spencer',
#   'genre': 'Iure',
#   'content': 'I know.'},
#  {'title': "Will you, won't.",
#   'author': 'Kareem Lang',
#   'genre': 'Sit',
#   'content': 'GAVE HER.'},
#  {'title': "Alice, 'we learned.",
#   'author': 'Cortez Olson',
#   'genre': 'Dolor',
#   'content': 'Alice.'},
#  {'title': "Duchess; 'I never.",
#   'author': 'Chet Kub',
#   'genre': 'Et',
#   'content': 'Mock.'},
#  {'title': 'Alice to herself.',
#   'author': "Brandi O'Keefe",
#   'genre': 'Non',
#   'content': 'Alice.'},
#  {'title': 'Seaography: then.',
#   'author': 'Kaycee Hane',
#   'genre': 'Recusandae',
#   'content': 'I can go.'},
#  {'title': 'Alice for some.',
#   'author': 'Leanna Wisozk',
#   'genre': 'Qui',
#   'content': 'THAT.'},
#  {'title': 'Improve his.',
#   'author': 'Jaron Kovacek',
#   'genre': 'Eos',
#   'content': 'I shall.'},
#  {'title': 'Laughing and.',
#   'author': 'Beryl Abbott',
#   'genre': 'Iure',
#   'content': 'Bill!.'},
#  {'title': 'And the muscular.',
#   'author': 'Ariel Herzog',
#   'genre': 'Minima',
#   'content': 'Alice.'},
#  {'title': "YOUR table,' said.",
#   'author': 'Rhoda Ortiz',
#   'genre': 'Explicabo',
#   'content': 'Alice.'},
#  {'title': "Mock Turtle's.",
#   'author': 'Tyrel Hettinger',
#   'genre': 'Cum',
#   'content': 'And the.'},
#  {'title': "ME,' but.",
#   'author': "Kelli D'Amore",
#   'genre': 'Expedita',
#   'content': 'Duck and.'},
#  {'title': 'Gryphon repeated.',
#   'author': 'Tatyana Keeling',
#   'genre': 'Officia',
#   'content': "Rabbit's."},
#  {'title': 'The only things in.',
#   'author': 'Elaina DuBuque',
#   'genre': 'Dolorem',
#   'content': 'Alice.'},
#  {'title': 'The rabbit-hole.',
#   'author': "Michel O'Reilly",
#   'genre': 'Provident',
#   'content': 'Tillie.'},
#  {'title': 'The first witness.',
#   'author': 'Marcelle Langosh',
#   'genre': 'Reiciendis',
#   'content': 'Alice.'},
#  {'title': 'March Hare and his.',
#   'author': 'Catherine Block',
#   'genre': 'Facere',
#   'content': 'Queen.'},
#  {'title': 'Gryphon in an.',
#   'author': 'Tony Satterfield',
#   'genre': 'Dolorum',
#   'content': 'King say.'},
#  {'title': 'Alice heard the.',
#   'author': 'Kareem Kovacek',
#   'genre': 'Velit',
#   'content': 'Alice.'},
#  {'title': 'I will prosecute.',
#   'author': 'Hobart Kris',
#   'genre': 'Ut',
#   'content': 'THAT.'},
#  {'title': 'It was opened by.',
#   'author': 'Mariam Ward',
#   'genre': 'Qui',
#   'content': "I'd."},
#  {'title': "No, no! You're a.",
#   'author': "Danial O'Reilly",
#   'genre': 'Voluptates',
#   'content': 'King.'},
#  {'title': 'There seemed to be.',
#   'author': 'Odie Price',
#   'genre': 'Totam',
#   'content': 'However.'},
#  {'title': "Caucus-race.'.",
#   'author': 'Hassan Kemmer',
#   'genre': 'Dolorem',
#   'content': 'She was.'},
#  {'title': "Dormouse shall!'.",
#   'author': 'Narciso Ritchie',
#   'genre': 'Aut',
#   'content': 'So she.'},
#  {'title': 'Mock Turtle, who.',
#   'author': 'Allie Reynolds',
#   'genre': 'Ipsam',
#   'content': 'After a.'},
#  {'title': 'The Hatter was the.',
#   'author': 'Destin Walker',
#   'genre': 'Et',
#   'content': '.'},
#  {'title': 'King said, turning.',
#   'author': 'David Murray',
#   'genre': 'Impedit',
#   'content': 'Alice.'},
#  {'title': 'THEN--she found.',
#   'author': 'Pattie Weimann',
#   'genre': 'Laboriosam',
#   'content': 'But do.'},
#  {'title': 'Caterpillar. Alice.',
#   'author': 'Jovany Runolfsdottir',
#   'genre': 'Quos',
#   'content': 'Alice.'},
#  {'title': 'Alice thought she.',
#   'author': 'Stuart Thompson',
#   'genre': 'Facere',
#   'content': 'The.'},
#  {'title': 'As soon as look at.',
#   'author': 'Troy Hickle',
#   'genre': 'Eligendi',
#   'content': 'He got.'},
#  {'title': 'Lizard, who seemed.',
#   'author': 'Lesley Schimmel',
#   'genre': 'Dicta',
#   'content': 'Alice.'},
#  {'title': "Alice, 'it would.",
#   'author': 'Bryce Connelly',
#   'genre': 'Libero',
#   'content': 'Alice.'},
#  {'title': 'Duchess.',
#   'author': 'Sylvester Schmeler',
#   'genre': 'Iusto',
#   'content': 'Soup of.'},
#  {'title': "Hatter, 'I cut.",
#   'author': 'Elenora Gibson',
#   'genre': 'Ad',
#   'content': 'Gryphon.'},
#  {'title': 'I mentioned.',
#   'author': 'Enoch Conn',
#   'genre': 'Assumenda',
#   'content': 'Alice.'},
#  {'title': 'Alice could see.',
#   'author': 'Madaline Lehner',
#   'genre': 'In',
#   'content': 'Alice.'},
#  {'title': "I can't show it.",
#   'author': 'Piper Yost',
#   'genre': 'Eos',
#   'content': 'It was.'},
#  {'title': 'The Panther took.',
#   'author': 'Cruz Stokes',
#   'genre': 'Quo',
#   'content': 'PLEASE.'},
#  {'title': 'Caterpillar. Alice.',
#   'author': 'Molly Gottlieb',
#   'genre': 'Consequatur',
#   'content': 'I.'},
#  {'title': 'WOULD always get.',
#   'author': 'Missouri Runolfsdottir',
#   'genre': 'Ipsam',
#   'content': "I'm."},
#  {'title': 'Mock Turtle went.',
#   'author': 'Norene Schmeler',
#   'genre': 'Eum',
#   'content': 'Lory, as.'},
#  {'title': 'What made you so.',
#   'author': 'Ona Abernathy',
#   'genre': 'Optio',
#   'content': 'Pigeon.'},
#  {'title': 'WOULD go with the.',
#   'author': 'Edmond Grant',
#   'genre': 'Voluptatum',
#   'content': 'Number.'},
#  {'title': 'VERY remarkable in.',
#   'author': 'Junior Kling',
#   'genre': 'Molestias',
#   'content': 'There.'},
#  {'title': 'Alice soon began.',
#   'author': 'Dion Hamill',
#   'genre': 'Tempore',
#   'content': 'This is.'},
#  {'title': 'Lory, as soon as.',
#   'author': 'Caterina Labadie',
#   'genre': 'Quae',
#   'content': 'Queen in.'},
#  {'title': 'Mock Turtle had.',
#   'author': 'Wilford Conn',
#   'genre': 'Dolore',
#   'content': 'Alice.'},
#  {'title': "Caterpillar. 'I'm.",
#   'author': 'Ernesto Bashirian',
#   'genre': 'Reiciendis',
#   'content': 'And oh.'},
#  {'title': 'Queen, but she.',
#   'author': 'Donnell Bogisich',
#   'genre': 'Aperiam',
#   'content': 'I was.'},
#  {'title': "Dormouse: 'not in.",
#   'author': 'Jess Olson',
#   'genre': 'Et',
#   'content': 'I will.'},
#  {'title': 'I know THAT well.',
#   'author': 'Breana Nader',
#   'genre': 'Nulla',
#   'content': 'So they.'},
#  {'title': 'THEN--she found.',
#   'author': 'Tracey Nicolas',
#   'genre': 'Ut',
#   'content': 'Hatter.'},
#  {'title': 'Alice hastily.',
#   'author': 'Marshall Lockman',
#   'genre': 'Aut',
#   'content': 'Oh, I.'},
#  {'title': "I'll set Dinah at.",
#   'author': 'Hildegard Goodwin',
#   'genre': 'Sed',
#   'content': 'Lory.'},
#  {'title': 'Gryphon, and.',
#   'author': 'Junior Cartwright',
#   'genre': 'Dolore',
#   'content': 'I to get.'},
#  {'title': 'Alice was too much.',
#   'author': 'Narciso Conn',
#   'genre': 'Expedita',
#   'content': 'King.'},
#  {'title': 'Caterpillar. Alice.',
#   'author': 'Weston Volkman',
#   'genre': 'Voluptatem',
#   'content': 'Queen.'},
#  {'title': 'Queen never left.',
#   'author': 'Anabelle Schuppe',
#   'genre': 'Et',
#   'content': 'Gryphon.'},
#  {'title': 'Alice, and she.',
#   'author': 'Raul Jacobson',
#   'genre': 'Nihil',
#   'content': '.'},
#  {'title': "I don't take this.",
#   'author': 'Willa Willms',
#   'genre': 'Aliquam',
#   'content': 'King in.'},
#  {'title': "LESS,' said the.",
#   'author': 'Monte Kulas',
#   'genre': 'Ratione',
#   'content': 'Dinah.'},
#  {'title': "I'm grown up now,'.",
#   'author': 'Elvie Senger',
#   'genre': 'Consectetur',
#   'content': "I can't."},
#  {'title': "Why, she'll eat a.",
#   'author': 'Maude Schmeler',
#   'genre': 'Sed',
#   'content': 'I wonder.'},
#  {'title': 'March Hare had.',
#   'author': 'Kaylie Swaniawski',
#   'genre': 'Aut',
#   'content': 'I.'},
#  {'title': 'Alice soon came to.',
#   'author': 'Jeromy Miller',
#   'genre': 'Fugiat',
#   'content': 'Alice.'},
#  {'title': 'But at any rate.',
#   'author': 'Dave Tillman',
#   'genre': 'Velit',
#   'content': 'Be off.'},
#  {'title': 'Dodo solemnly.',
#   'author': 'Domingo Gutkowski',
#   'genre': 'Dolorum',
#   'content': 'A bright.'}]

# %% [markdown]
# ### Retorno de una API

# %% [markdown]
# Así como esta API, existen muchas otras. No todas responden en formato JSON.

# %%
# Podemos usar una API para obtener nuestra IP pública
# Notar que no estamos transformando a JSON
response = requests.get('https://api.ipify.org')
ip = response.text
print(response.status_code, ip)

# %%
# Podemos ahora usar una API para obtener la latitud y 
# longitud en la que nos encontramos al momento de correr este código
response = requests.get(f'https://ipapi.co/{ip}/latlong/')
print(response.status_code, response.text)

# %% [markdown]
# Por temas de seguridad, muchas de las APIs públicas necesitan una llave/clave para poder utilizarlas. Para conseguir estas *keys* en general debes crearte una cuenta. De esta forma se mantiene control de la aplicación expuesta, quiénes están accediendo a ella, con qué frecuencia, etc.

# %%
# Además, podemos usar otra API para ver más descripciones de la IP utilizada
url = 'http://api.ipstack.com/'
# En este caso puedes usar esta `API_KEY` para probar
API_KEY = 'c657ed216cf3e05d129bd6b2ccb8589e'
# Recibe la API_KEY como parámetro

# Esto puede ser enviado de dos formas:

# 1. Agregando los parámetros en la URL:
pais = requests.get('{}/{}?access_key={}'.format(url, ip, API_KEY))

# 2. Pasando los parámetros en el método:
pais = requests.get(f'{url}/{ip}', params={'access_key': API_KEY})

# %%
pais.status_code
# Out:
# 200

# %%
pais.headers
# Out:
# {'content-type': 'application/json', 'transfer-encoding': 'chunked', 'date': 'Wed, 12 Apr 2023 04:35:39 GMT', 'x-apilayer-transaction-id': 'bf8e6f83-11c6-473a-a091-3525f1c4170b', 'access-control-allow-origin': '*', 'access-control-allow-methods': 'GET, POST, HEAD, OPTIONS', 'access-control-allow-headers': '*', 'x-quota-limit': '100', 'x-quota-remaining': '89', 'x-increment-usage': '1', 'x-request-time': '0.026'}

# %%
# En este caso la API sí retorna un JSON
pais.json()
# Out:
# {'ip': '181.43.208.216',
#  'type': 'ipv4',
#  'continent_code': 'SA',
#  'continent_name': 'South America',
#  'country_code': 'CL',
#  'country_name': 'Chile',
#  'region_code': 'RM',
#  'region_name': 'Santiago Metropolitan',
#  'city': 'Santiago',
#  'zip': None,
#  'latitude': -33.46500015258789,
#  'longitude': -70.65599822998047,
#  'location': {'geoname_id': 3871336,
#   'capital': 'Santiago',
#   'languages': [{'code': 'es', 'name': 'Spanish', 'native': 'Español'}],
#   'country_flag': 'https://assets.ipstack.com/flags/cl.svg',
#   'country_flag_emoji': '🇨🇱',
#   'country_flag_emoji_unicode': 'U+1F1E8 U+1F1F1',
#   'calling_code': '56',
#   'is_eu': False}}

# %% [markdown]
# ### Uso de `post`

# %% [markdown]
# En el caso de la API con la que hemos estado haciendo estas pruebas, solo se ofrecen servicios para realizar consultas, lo que se puede llevar a cabo utilizando el método `GET` del protocolo HTTP. Sin embargo, muchas veces queremos crear recursos en nuestro servidor, como por ejemplo crear un nuevo artículo para un *blog*, y para esto debemos utilizar el método `POST` del protocolo.
#
# La API de `JSONPlaceholder` nos permite simular el uso de una API real, sin que verdaderamente exista un servicio detrás de esta. En este caso la utilizaremos para simular la creación de un artículo para un *blog*. En la práctica no estará ocurriendo nada en el servidor, puesto que es solo una simulación, pero en la vida real uno esperaría que como respuesta a nuestra *request* se cree una entrada en la base de datos del servicio que estamos utilizando. Pueden ver más información de como usar esta API [aquí](https://jsonplaceholder.typicode.com/).
#
# A diferencia del método `GET`, cuando utilizamos el método `POST` podemos enviar información a la API utilizando el parámetro `data`, al cual podemos pasarle un diccionario de Python con la información que queremos enviar. Para este ejemplo debemos enviar la información de un artículo noticioso que queremos crear.

# %%
# Extracto de un artículo proveniente del blog https://venezolanoenchile.com/2016/01/20/como-es-el-clima-en-santiago-de-chile/
cuerpo = '''
El clima de Santiago es muy extraño para los que venimos de un país tropical como Venezuela y, 
más aún, para los que vivíamos en Maracaibo, como yo.\nUn día de verano, mientras caminaba a eso 
de las 2pm hacia mi trabajo, me puse a pensar en los temas que no he tocado aún en el blog. 
En ese momento, con 32°C de temperatura y bajo el sol, decidí escribir sobre este tema.

Chile es un país que tiene muchos tipos de clima, desde el desértico hasta el frío antártico. 
Pero como yo no conozco ninguna otra ciudad de Chile que no sea Santiago, todo lo que diré a 
continuación será de la capital.'
'''

data = {
    'title': '¿Cómo es el clima en Santiago de Chile?',
    'body': cuerpo,
    'userId': 1,
}


noticia = requests.post('https://jsonplaceholder.typicode.com/posts', data=data)

# %%
# Vemos que obtenemos un código de que nuestro artículo fue creado
print(noticia.status_code)
print(noticia.reason)

# Esta API nos retorna un JSON con el mismo recurso creado, nótese que se le asignó un id al artículo
data = noticia.json() 
print(data.keys())
# Out:
# 201
# Created
# dict_keys(['title', 'body', 'userId', 'id'])

# %%
print(str(data['id']) + "\n")
print(data['title'] + "\n")
print(data['body'])
# Out:
# 101
#
# ¿Cómo es el clima en Santiago de Chile?
#
#
# El clima de Santiago es muy extraño para los que venimos de un país tropical como Venezuela y,
# más aún, para los que vivíamos en Maracaibo, como yo.
# Un día de verano, mientras caminaba a eso
# de las 2pm hacia mi trabajo, me puse a pensar en los temas que no he tocado aún en el blog.
# En ese momento, con 32°C de temperatura y bajo el sol, decidí escribir sobre este tema.
#
# Chile es un país que tiene muchos tipos de clima, desde el desértico hasta el frío antártico.
# Pero como yo no conozco ninguna otra ciudad de Chile que no sea Santiago, todo lo que diré a
# continuación será de la capital.'

# %% [markdown]
# ### Autenticación en _headers_

# %% [markdown]
# Aparte del método `post`, tambien tenemos `.put()`, `.patch()` o `.delete()`. Generalmente, este tipo de requests repercuten en la modificación de una base de datos, y para lograr esto, muchas veces es necesario tener una autorización previa.
#
# Es aquí que surge la necesidad de ocupar el parámetro `headers` que permite incluir información en la cabezara de la solicitud incuyendo, por ejemplo, un token especial de acceso que a la API le sirve para identificarte y verificar si tienes los permisos.
#
# Utilizar este parámetro es análogo a `data`. Solo es necesario crear un diccionario e incluirlo en la _requests_. Las llaves del diccionario puede cambiar según la API que queramos acceder.

# %%
my_headers = {
    "Authorization": "MI-TOKEN"
}

data = {
    'title': 'Probando',
    'body': 'Probando',
    'userId': 11,
}

requests.post('https://jsonplaceholder.typicode.com/posts', headers=my_headers, data=data)
# Out:
# <Response [201]>

# %% [markdown]
# ### Caso aplicado: API de GITHUB

# %% [markdown]
# A continuación, te presentamos un caso aplicado para crear una _issue_ en un repositorio de Github mediante su API.  En este caso, la API de Github pide que el `data` a enviar sea un diccionario en su forma de _string_, es decir, `json.dumps(data)`.
#
# Además, para que este caso aplicado funcione correctamante, se requiere:
#
# 1. Completar `github_repo` con el nombre de tu repositorio de github dado en el curso. Por ejemplo: `"juanito-iic2233-20XX-1"`
# 2. Completar `token` con un _access token_ generado en Github. Puedes generar uno en [esta página](https://github.com/settings/tokens/new). Este _token_ debe tener al menos el siguiente permiso para poder crear una issue: _Full control of private repositories_.

# %%
import json  # noqa: E402

github_repo = 'juanito-iic2233-20XX-1'
token = "COMPLETAR"

body = {
    'title': "Creando una issue con la API",
    'body': "Ahora tengo el poder para hacer issues desde Python! 🎉"
}

my_headers = {
    'Authorization': 'token ' + token,
    'Accept': 'application/vnd.github.v3+json'
}

url = f"https://api.github.com/repos/IIC2233/{github_repo}/issues"

response = requests.post(url, data=json.dumps(body), headers=my_headers)
response.status_code

# %% [markdown]
# Si la celda anterior arrojó un `201`. Significa que el _token_ utilizado y el `github_repo` estaban correctos, así que se creó la _issue_. Ejecuta la siguiente celda para ver el _link_ a dicha issue.

# %%
response.json()["html_url"]

# %% [markdown]
# ## *Server-side App*
#
# La misión principal del servidor es disponer el contenido para que pueda ser consultado mediante un *web service*. La aplicación que corre en el servidor es la encargada de la lógica e interacción entre cliente-servidor. La información que viaja entre un cliente y un servidor permite generar comunicación entre aplicaciones.
#
# Una aplicación puede estar desarrollada en cualquier lenguaje de programación que permita exponer una API para ser consumida por otras aplicaciones a través de la web. Por ejemplo, podemos tener una aplicación corriendo en Java, y desde nuestro código en Python acceder a esa API.
#
# En Python existe [WSGI](https://docs.python.org/es/3/library/wsgiref.html) para exponer APIs. Tambien existen varios *frameworks* de programación que facilitan esta misma tarea, como **Flask** y **Django**. Además, puedes montar tus aplicaciones en servicios o servidores ya disponibles en la web, provistos como Platform-as-a-Service (PaaS) o Infrastructure-as-a-Service (IaaS). Por ejemplo, puedes usar **Heroku** (PaaS), **Digital Ocean** (IaaS), o **Microsoft Azure** (PaaS) para disponer tus APIs en una red pública con alta disponibilidad.

# %% [markdown]
# Al igual que lo hecho en *networking*, que dejábamos corriendo un servidor que estaba recibiendo solicitudes dentro del computador, podemos hacer lo mismo con *webservices* y tener un servidor corriendo que solo recibe solicitudes dentro del mismo computador.
#
# A modo de ejemplo, tenemos una pequeña API utilizando WSGI para levantar una aplicación que responde algunos mensajes.
#
# Antes de empezar, debes ejecutar el archivo `servidor.py` en la terminal o en VSCode para levantar esta API. Luego, puedes ejecutar las siguientes celdas donde utilizaremos `requests` para realizar solicitudes a esta API.

# %%
# La URL base de la API creada
BASE_URL = "http://localhost:4444/"

# Podemos consultar a esta ruta
solicitud = requests.get(BASE_URL)
solicitud.status_code
# Out:
# 200

# %%
solicitud.json()

print(solicitud.json()['message'])
# Out:
# Hello World

# %%
# ¡Vamos a despedirnos haciendo una consulta a otro endpoint de nuestra API!
respuesta = requests.get(BASE_URL + "goodbye/")
print(respuesta.status_code, respuesta.json())
# Out:
# 200 {'message': 'Que la fuerza NO esté contigo'}

# %% [markdown]
# **Te invitamos a consumir diferentes APIs desde Python para poner a prueba este contenidos**. Algunas ideas de estudio pueden ser:
# - Revisar los diferentes _endpoint_ que tenía [fakerapi](https://fakerapi.it/en) para inventar más información.
# - Revisar la documentación de [OMDb API](http://www.omdbapi.com/#usage) para buscar películas.
# - Usar la APi de [pokemon](https://pokeapi.co/docs/v2#pokemon) para buscar información de tu pokemon favorito.
